# %%
import pandas as pd

# %%
high_mass_central_df = pd.read_parquet ('../high_mass_central_df_annuli_revised.parquet')

# %%
high_mass_central_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 0           0.0   0.010883   10.939674 -1.120602      7.966769
# 1           0.0   0.032649   10.494615 -1.556470      7.919378
# 2           0.0   0.054415    9.982732 -2.017950      7.934402
# 3           0.0   0.076182    9.739688 -2.263846      7.927703
# 4           0.0   0.097948    9.594884 -2.389380      7.926022
# ...         ...        ...         ...       ...           ...
# 54984  594444.0   0.169860    9.321200 -2.636930      6.265163
# 54985  594444.0   0.509579    8.999712 -1.776677      6.709038
# 54986  594444.0   0.849298    8.734355 -3.316755      7.059817
# 54987  594444.0   1.189017    8.498129 -3.504491      6.857232
# 54988  594444.0   1.528736    8.287459 -3.689198      6.383893
#
#        quenching_vector      gas_mass      s_mass    BHMass  class  \
# 0                     0  19187.548828  370.558472  0.700941      0
# 1                     0  19187.548828  370.558472  0.700941      0
# 2                     0  19187.548828  370.558472  0.700941      0
# 3                     1  19187.548828  370.558472  0.700941      0
# 4                     1  19187.548828  370.558472  0.700941      0
# ...                 ...           ...         ...       ...    ...
# 54984                 1      0.000000    2.942021  0.006637      0
# 54985                 0      0.000000    2.942021  0.006637      0
# 54986                 1      0.000000    2.942021  0.006637      0
# 54987                 1      0.000000    2.942021  0.006637      0
# 54988                 1      0.000000    2.942021  0.006637      0
#
#           veldisp  global_SFRs      BH_cumQM       BH_cumRM         Mhalo  \
# 0      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 1      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 2      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 3      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 4      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# ...           ...          ...           ...            ...           ...
# 54984   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54985   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54986   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54987   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54988   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
#
#             overdens     bulge      Bfld        BH_AGN
# 0      102677.912949  0.982283  0.205462  5.678228e+08
# 1      102677.912949  0.982283  0.205462  5.678228e+08
# 2      102677.912949  0.982283  0.205462  5.678228e+08
# 3      102677.912949  0.982283  0.205462  5.678228e+08
# 4      102677.912949  0.982283  0.205462  5.678228e+08
# ...              ...       ...       ...           ...
# 54984      19.981537 -0.021362  0.070190  2.062991e+04
# 54985      19.981537 -0.021362  0.070190  2.062991e+04
# 54986      19.981537 -0.021362  0.070190  2.062991e+04
# 54987      19.981537 -0.021362  0.070190  2.062991e+04
# 54988      19.981537 -0.021362  0.070190  2.062991e+04
#
# [26899 rows x 19 columns]

# %%
# # calculating star forming efficiency (SFE) and gas fraction 
# high_mass_central_df['SFE'] = 10**(high_mass_central_df['avg_SFR'] - high_mass_central_df['avg_gas_mass'])
# high_mass_central_df['f_gas'] = 10**(high_mass_central_df['avg_gas_mass'] - high_mass_central_df['avg_s_mass'])

# %%
high_mass_central_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 0           0.0   0.010883   10.939674 -1.120602      7.966769
# 1           0.0   0.032649   10.494615 -1.556470      7.919378
# 2           0.0   0.054415    9.982732 -2.017950      7.934402
# 3           0.0   0.076182    9.739688 -2.263846      7.927703
# 4           0.0   0.097948    9.594884 -2.389380      7.926022
# ...         ...        ...         ...       ...           ...
# 54984  594444.0   0.169860    9.321200 -2.636930      6.265163
# 54985  594444.0   0.509579    8.999712 -1.776677      6.709038
# 54986  594444.0   0.849298    8.734355 -3.316755      7.059817
# 54987  594444.0   1.189017    8.498129 -3.504491      6.857232
# 54988  594444.0   1.528736    8.287459 -3.689198      6.383893
#
#        quenching_vector      gas_mass      s_mass    BHMass  class  \
# 0                     0  19187.548828  370.558472  0.700941      0
# 1                     0  19187.548828  370.558472  0.700941      0
# 2                     0  19187.548828  370.558472  0.700941      0
# 3                     1  19187.548828  370.558472  0.700941      0
# 4                     1  19187.548828  370.558472  0.700941      0
# ...                 ...           ...         ...       ...    ...
# 54984                 1      0.000000    2.942021  0.006637      0
# 54985                 0      0.000000    2.942021  0.006637      0
# 54986                 1      0.000000    2.942021  0.006637      0
# 54987                 1      0.000000    2.942021  0.006637      0
# 54988                 1      0.000000    2.942021  0.006637      0
#
#           veldisp  global_SFRs      BH_cumQM       BH_cumRM         Mhalo  \
# 0      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 1      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 2      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 3      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 4      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# ...           ...          ...           ...            ...           ...
# 54984   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54985   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54986   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54987   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54988   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
#
#             overdens     bulge      Bfld        BH_AGN
# 0      102677.912949  0.982283  0.205462  5.678228e+08
# 1      102677.912949  0.982283  0.205462  5.678228e+08
# 2      102677.912949  0.982283  0.205462  5.678228e+08
# 3      102677.912949  0.982283  0.205462  5.678228e+08
# 4      102677.912949  0.982283  0.205462  5.678228e+08
# ...              ...       ...       ...           ...
# 54984      19.981537 -0.021362  0.070190  2.062991e+04
# 54985      19.981537 -0.021362  0.070190  2.062991e+04
# 54986      19.981537 -0.021362  0.070190  2.062991e+04
# 54987      19.981537 -0.021362  0.070190  2.062991e+04
# 54988      19.981537 -0.021362  0.070190  2.062991e+04
#
# [26899 rows x 19 columns]

# %%
high_mass_central_df['quenching_vector'].hist()
# Out:
# <Axes: >

# %%
galaxy_class_counts = high_mass_central_df.groupby("subID")["quenching_vector"].nunique()

# count galaxies with only one class vs. two classes
num_single_class_galaxies = (galaxy_class_counts == 1).sum()
num_two_class_galaxies = (galaxy_class_counts > 1).sum()

print(f"Number of galaxies with only one class: {num_single_class_galaxies}")
print(f"Number of galaxies with two classes: {num_two_class_galaxies}")
# Out:
# Number of galaxies with only one class: 713
# Number of galaxies with two classes: 1186

# %%
import numpy as np

# galaxy_class_counts = low_mass_satellite_df.groupby("subID")["quenching_vector"].nunique()


# # single-class and multi-class galaxies
# single_class_galaxies = galaxy_class_counts[galaxy_class_counts == 1].index
# multi_class_galaxies = galaxy_class_counts[galaxy_class_counts > 1].index

# # keep a random fraction
# fraction_to_keep = 1 
# kept_single_class_galaxies = np.random.choice(single_class_galaxies, 
#                                               size=int(len(single_class_galaxies) * fraction_to_keep), 
#                                               replace=False)

# filtered_galaxies = np.concatenate([kept_single_class_galaxies, multi_class_galaxies])

# filtered_df = low_mass_satellite_df[low_mass_satellite_df["subID"].isin(filtered_galaxies)]

# print(f"Original dataset size: {low_mass_satellite_df.shape}")
# print(f"Filtered dataset size: {filtered_df.shape}")

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
high_mass_central_df = high_mass_central_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "avg_SFR", "avg_gas_mass","gas_mass", "Bfld", "veldisp", "BH_AGN"])
high_mass_central_df.duplicated()

# X = low_mass_satellite_df.drop(['quenching_vector'], axis=1)
# y = low_mass_satellite_df['quenching_vector']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54984    False
# 54985    False
# 54986    False
# 54987    False
# 54988    False
# Length: 26899, dtype: bool

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedGroupKFold


# splitting galaxies into test/train based on subID
unique_galaxies = np.unique(high_mass_central_df['subID'])

train_aucs = []
test_aucs = []
feature_importances_list = []
feature_names = None
train_f1s = []
test_f1s = []


for seed in range(10):
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    train_data = high_mass_central_df[high_mass_central_df['subID'].isin(train_galaxies)]
    test_data = high_mass_central_df[high_mass_central_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['quenching_vector', 'subID']), train_data['quenching_vector']
    X_test, y_test = test_data.drop(columns=['quenching_vector', 'subID']), test_data['quenching_vector']

    if feature_names is None:
        feature_names = X_train.columns.tolist()
    # scaling
    scaler = RobustScaler()
    X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
    X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

    param_grid = {
    'n_estimators': [100,200, 300, 400, 500],  
    'max_depth': [50, 100, 150, 200, 250],  
    'min_samples_split': [50, 100, 150],  
    'min_samples_leaf': [500,600],  
#     'max_features': ['sqrt', 'log2'],  
    'max_features': [None],  
    'bootstrap': [True],
    'class_weight':['balanced']
    }
    rf = RandomForestClassifier(random_state=seed)
    groups_train = train_data['subID']
    cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=seed)

    random_search = RandomizedSearchCV(
    estimator=rf, 
    param_distributions=param_grid, 
    n_iter=10,
    cv=cv, 
    scoring='roc_auc',
    n_jobs=-1,
    random_state=seed,
    verbose=2)

    random_search.fit(X_train_scaled, y_train, groups=groups_train)

    best_rf = random_search.best_estimator_

    y_train_prob = best_rf.predict_proba(X_train_scaled)[:, 1]
    y_test_prob = best_rf.predict_proba(X_test_scaled)[:, 1]

    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
    fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

    # ROC curves
    plt.figure(figsize=(8,6))
    plt.plot(fpr_train, tpr_train, label=f'Train AUC = {roc_auc_score(y_train, y_train_prob):.3f}')
    plt.plot(fpr_test, tpr_test, label=f'Test AUC = {roc_auc_score(y_test, y_test_prob):.3f}')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves')
    plt.legend()
    plt.grid(True)
    plt.show()
    print(random_search.best_params_)

    
    # aucs and feature importance
    train_auc = roc_auc_score(y_train, y_train_prob)
    test_auc = roc_auc_score(y_test, y_test_prob)
    feature_importances_list.append(best_rf.feature_importances_)
    
    train_aucs.append(train_auc)
    test_aucs.append(test_auc)


    y_train_pred = best_rf.predict(X_train_scaled)
    y_test_pred = best_rf.predict(X_test_scaled)

    # f1 scores
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1s.append(train_f1)
    test_f1s.append(test_f1)
    
print("\nAverage AUC over 10 runs:")
print(f"Train AUC: Mean = {np.mean(train_aucs):.4f}, Std = {np.std(train_aucs):.4f}")
print(f"Test AUC:  Mean = {np.mean(test_aucs):.4f}, Std = {np.std(test_aucs):.4f}")
print(f"Train F1: Mean = {np.mean(train_f1s):.4f}, Std = {np.std(train_f1s):.4f}")
print(f"Test F1:  Mean = {np.mean(test_f1s):.4f}, Std = {np.std(test_f1s):.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  11.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=300; total time=   7.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=300; total time=   7.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=300; total time=   7.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=  10.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   5.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.5s
# {'n_estimators': 400, 'min_samples_split': 50, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 100, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=   9.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=   9.7s
# {'n_estimators': 500, 'min_samples_split': 150, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 50, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   7.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   7.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  11.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  11.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  11.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  12.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  11.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  11.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   8.6s
# {'n_estimators': 200, 'min_samples_split': 100, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 50, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   8.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   8.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=400; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=400; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=400; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=400; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=400; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=   9.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   8.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   7.3s
# {'n_estimators': 100, 'min_samples_split': 100, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 150, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   6.7s
# {'n_estimators': 500, 'min_samples_split': 150, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 50, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   7.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  10.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  10.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  10.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  10.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=100; total time=   2.3s
# ...
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  11.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   5.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   5.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  10.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  11.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  11.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   7.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   7.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  11.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  10.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  10.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=   8.1s
# {'n_estimators': 100, 'min_samples_split': 100, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 150, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   6.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   6.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   8.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  10.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  11.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  11.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  10.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=   8.3s
# {'n_estimators': 500, 'min_samples_split': 100, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 50, 'class_weight': 'balanced', 'bootstrap': True}
#
# Average AUC over 10 runs:
# Train AUC: Mean = 0.8265, Std = 0.0055
# Test AUC:  Mean = 0.8074, Std = 0.0074
# Train F1: Mean = 0.7282, Std = 0.0096
# Test F1:  Mean = 0.7114, Std = 0.0128

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
#      'Bfld': '#EEDD88',
#     'veldisp': '#CC3311',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("HMC Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 3      BHMass         0.577930  0.023107
# 1  avg_s_mass         0.221398  0.025903
# 6       bulge         0.107293  0.013722
# 2      s_mass         0.070414  0.020880
# 5    overdens         0.017963  0.023696
# 4       Mhalo         0.003012  0.002381
# 0   bin_radii         0.001991  0.001344

# %%
import os
# Define your directory and file name
directory = 'rf_classification_outputs'
filename = 'hmc_rf_quenching.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to rf_classification_outputs/hmc_rf_quenching.csv

# %%
train_mean = round(np.mean(train_aucs), 2)
test_mean = round(np.mean(test_aucs), 2)
print(train_mean)
df = pd.DataFrame({
    'Train AUC': [train_mean],
    'Test AUC': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'rf_classification_outputs'
filename = 'hmc_rf_quenching_auc.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# 0.83
#    Train AUC  Test AUC
# 0       0.83      0.81
# DataFrame saved to rf_classification_outputs/hmc_rf_quenching_auc.csv

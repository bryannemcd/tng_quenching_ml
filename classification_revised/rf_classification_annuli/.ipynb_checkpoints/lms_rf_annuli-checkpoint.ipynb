# %%
import pandas as pd

# %%
low_mass_satellite_df = pd.read_parquet ('../low_mass_satellite_df_annuli_revised.parquet')

# %%
low_mass_satellite_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 439        37.0   0.174505    8.905776 -0.052619      8.682093
# 440        37.0   0.523516    8.636583 -0.643683      8.302815
# 441        37.0   0.872526    8.421218 -1.414926      7.867777
# 442        37.0   1.221537    8.243556 -1.699316      7.714798
# 443        37.0   1.570547    8.094305 -1.657207      7.711024
# ...         ...        ...         ...       ...           ...
# 54860  593573.0   0.461125    7.915781 -3.874264      7.566107
# 54861  593573.0   0.768541    7.496673 -2.880743      7.366165
# 54862  593573.0   1.075957    7.168706 -3.435107      7.380437
# 54863  593573.0   1.383374    6.925375 -3.566125      7.352052
# 54864  593573.0   1.690790    6.711826 -3.168819      7.341474
#
#        quenching_vector  gas_mass    s_mass    BHMass  class    veldisp  \
# 439                   0  0.022175  1.336990  0.003621      1  77.483803
# 440                   0  0.022175  1.336990  0.003621      1  77.483803
# 441                   0  0.022175  1.336990  0.003621      1  77.483803
# 442                   0  0.022175  1.336990  0.003621      1  77.483803
# 443                   0  0.022175  1.336990  0.003621      1  77.483803
# ...                 ...       ...       ...       ...    ...        ...
# 54860                 1  0.000000  0.146896  0.000124      1  44.716286
# 54861                 0  0.000000  0.146896  0.000124      1  44.716286
# 54862                 0  0.000000  0.146896  0.000124      1  44.716286
# 54863                 0  0.000000  0.146896  0.000124      1  44.716286
# 54864                 0  0.000000  0.146896  0.000124      1  44.716286
#
#        global_SFRs     BH_cumQM       BH_cumRM         Mhalo    overdens  \
# 439       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 440       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 441       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 442       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 443       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# ...            ...          ...            ...           ...         ...
# 54860     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54861     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54862     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54863     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54864     0.059573     0.000000  1.027657e-321     21.333946    3.807714
#
#           bulge      Bfld         BH_AGN
# 439   -0.682291  0.694089   8.761890e+03
# 440   -0.682291  0.694089   8.761890e+03
# 441   -0.682291  0.694089   8.761890e+03
# 442   -0.682291  0.694089   8.761890e+03
# 443   -0.682291  0.694089   8.761890e+03
# ...         ...       ...            ...
# 54860 -0.044053  0.168837  1.027657e-321
# 54861 -0.044053  0.168837  1.027657e-321
# 54862 -0.044053  0.168837  1.027657e-321
# 54863 -0.044053  0.168837  1.027657e-321
# 54864 -0.044053  0.168837  1.027657e-321
#
# [5831 rows x 19 columns]

# %%
# # calculating star forming efficiency (SFE) and gas fraction 
# # bin_annuli returns the stellar mass, gas mass, and SFRs in log_10 space
# low_mass_satellite_df['SFE_local'] = 10**(low_mass_satellite_df['avg_SFR'] - low_mass_satellite_df['avg_gas_mass'])
# low_mass_satellite_df['f_gas_local'] = 10**(low_mass_satellite_df['avg_gas_mass'] - low_mass_satellite_df['avg_s_mass'])

# # drop rows where SFR and gas_mass are 0
# low_mass_satellite_df = low_mass_satellite_df[~((low_mass_satellite_df['global_SFRs'] == 0) & (low_mass_satellite_df['gas_mass'] == 0))]

# # creating copy to avoid set with copy warning
# low_mass_satellite_df = low_mass_satellite_df.copy()

# # if the gas mass is 0, set it to default value 10^-3.5
# mask = low_mass_satellite_df['gas_mass'] == 0.0
# low_mass_satellite_df.loc[mask, 'gas_mass'] = 10**(-3.5) * low_mass_satellite_df.loc[mask, 's_mass']


# low_mass_satellite_df['SFE_global'] = low_mass_satellite_df['global_SFRs']/low_mass_satellite_df['gas_mass']
# low_mass_satellite_df['f_gas_global'] = low_mass_satellite_df['gas_mass']/low_mass_satellite_df['s_mass']

# %%
low_mass_satellite_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 439        37.0   0.174505    8.905776 -0.052619      8.682093
# 440        37.0   0.523516    8.636583 -0.643683      8.302815
# 441        37.0   0.872526    8.421218 -1.414926      7.867777
# 442        37.0   1.221537    8.243556 -1.699316      7.714798
# 443        37.0   1.570547    8.094305 -1.657207      7.711024
# ...         ...        ...         ...       ...           ...
# 54860  593573.0   0.461125    7.915781 -3.874264      7.566107
# 54861  593573.0   0.768541    7.496673 -2.880743      7.366165
# 54862  593573.0   1.075957    7.168706 -3.435107      7.380437
# 54863  593573.0   1.383374    6.925375 -3.566125      7.352052
# 54864  593573.0   1.690790    6.711826 -3.168819      7.341474
#
#        quenching_vector  gas_mass    s_mass    BHMass  class    veldisp  \
# 439                   0  0.022175  1.336990  0.003621      1  77.483803
# 440                   0  0.022175  1.336990  0.003621      1  77.483803
# 441                   0  0.022175  1.336990  0.003621      1  77.483803
# 442                   0  0.022175  1.336990  0.003621      1  77.483803
# 443                   0  0.022175  1.336990  0.003621      1  77.483803
# ...                 ...       ...       ...       ...    ...        ...
# 54860                 1  0.000000  0.146896  0.000124      1  44.716286
# 54861                 0  0.000000  0.146896  0.000124      1  44.716286
# 54862                 0  0.000000  0.146896  0.000124      1  44.716286
# 54863                 0  0.000000  0.146896  0.000124      1  44.716286
# 54864                 0  0.000000  0.146896  0.000124      1  44.716286
#
#        global_SFRs     BH_cumQM       BH_cumRM         Mhalo    overdens  \
# 439       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 440       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 441       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 442       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 443       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# ...            ...          ...            ...           ...         ...
# 54860     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54861     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54862     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54863     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54864     0.059573     0.000000  1.027657e-321     21.333946    3.807714
#
#           bulge      Bfld         BH_AGN
# 439   -0.682291  0.694089   8.761890e+03
# 440   -0.682291  0.694089   8.761890e+03
# 441   -0.682291  0.694089   8.761890e+03
# 442   -0.682291  0.694089   8.761890e+03
# 443   -0.682291  0.694089   8.761890e+03
# ...         ...       ...            ...
# 54860 -0.044053  0.168837  1.027657e-321
# 54861 -0.044053  0.168837  1.027657e-321
# 54862 -0.044053  0.168837  1.027657e-321
# 54863 -0.044053  0.168837  1.027657e-321
# 54864 -0.044053  0.168837  1.027657e-321
#
# [5831 rows x 19 columns]

# %%
low_mass_satellite_df['quenching_vector'].hist()
# Out:
# <Axes: >

# %%
galaxy_class_counts = low_mass_satellite_df.groupby("subID")["quenching_vector"].nunique()

# count galaxies with only one class vs. two classes
num_single_class_galaxies = (galaxy_class_counts == 1).sum()
num_two_class_galaxies = (galaxy_class_counts > 1).sum()

print(f"Number of galaxies with only one class: {num_single_class_galaxies}")
print(f"Number of galaxies with two classes: {num_two_class_galaxies}")
# Out:
# Number of galaxies with only one class: 555
# Number of galaxies with two classes: 270

# %%
import numpy as np

# galaxy_class_counts = low_mass_satellite_df.groupby("subID")["quenching_vector"].nunique()


# # single-class and multi-class galaxies
# single_class_galaxies = galaxy_class_counts[galaxy_class_counts == 1].index
# multi_class_galaxies = galaxy_class_counts[galaxy_class_counts > 1].index

# # keep a random fraction
# fraction_to_keep = 1 
# kept_single_class_galaxies = np.random.choice(single_class_galaxies, 
#                                               size=int(len(single_class_galaxies) * fraction_to_keep), 
#                                               replace=False)

# filtered_galaxies = np.concatenate([kept_single_class_galaxies, multi_class_galaxies])

# filtered_df = low_mass_satellite_df[low_mass_satellite_df["subID"].isin(filtered_galaxies)]

# print(f"Original dataset size: {low_mass_satellite_df.shape}")
# print(f"Filtered dataset size: {filtered_df.shape}")

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
low_mass_satellite_df = low_mass_satellite_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "avg_SFR","avg_gas_mass", "gas_mass", "Bfld", "veldisp", "BH_AGN"])
low_mass_satellite_df.duplicated()

# X = low_mass_satellite_df.drop(['quenching_vector'], axis=1)
# y = low_mass_satellite_df['quenching_vector']
# Out:
# 439      False
# 440      False
# 441      False
# 442      False
# 443      False
#          ...
# 54860    False
# 54861    False
# 54862    False
# 54863    False
# 54864    False
# Length: 5831, dtype: bool

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedGroupKFold


# splitting galaxies into test/train based on subID
unique_galaxies = np.unique(low_mass_satellite_df['subID'])

train_aucs = []
test_aucs = []
feature_importances_list = []
feature_names = None
train_f1s = []
test_f1s = []


for seed in range(10):
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    train_data = low_mass_satellite_df[low_mass_satellite_df['subID'].isin(train_galaxies)]
    test_data = low_mass_satellite_df[low_mass_satellite_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['quenching_vector', 'subID']), train_data['quenching_vector']
    X_test, y_test = test_data.drop(columns=['quenching_vector', 'subID']), test_data['quenching_vector']

    if feature_names is None:
        feature_names = X_train.columns.tolist()
    # scaling
    scaler = RobustScaler()
    X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
    X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

    param_grid = {
    'n_estimators': [400, 500, 600],  
    'max_depth': [10, 20, 30, 40, 50],  
    'min_samples_split': [50, 100, 150],  
    'min_samples_leaf': [300, 400],  
    'max_features': [None],  
    'bootstrap': [True],
    'class_weight':['balanced']
    }
    rf = RandomForestClassifier(random_state=seed)
    groups_train = train_data['subID']
    cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=seed)

    random_search = RandomizedSearchCV(
    estimator=rf, 
    param_distributions=param_grid, 
    n_iter=10,
    cv=cv, 
    scoring='roc_auc',
    n_jobs=-1,
    random_state=seed,
    verbose=2)

    random_search.fit(X_train_scaled, y_train, groups=groups_train)

    best_rf = random_search.best_estimator_

    y_train_prob = best_rf.predict_proba(X_train_scaled)[:, 1]
    y_test_prob = best_rf.predict_proba(X_test_scaled)[:, 1]

    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
    fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

    # ROC curves
    plt.figure(figsize=(8,6))
    plt.plot(fpr_train, tpr_train, label=f'Train AUC = {roc_auc_score(y_train, y_train_prob):.3f}')
    plt.plot(fpr_test, tpr_test, label=f'Test AUC = {roc_auc_score(y_test, y_test_prob):.3f}')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves')
    plt.legend()
    plt.grid(True)
    plt.show()
    print(random_search.best_params_)

    
    # aucs and feature importance
    train_auc = roc_auc_score(y_train, y_train_prob)
    test_auc = roc_auc_score(y_test, y_test_prob)
    feature_importances_list.append(best_rf.feature_importances_)
    
    train_aucs.append(train_auc)
    test_aucs.append(test_auc)


    y_train_pred = best_rf.predict(X_train_scaled)
    y_test_pred = best_rf.predict(X_test_scaled)

    # f1 scores
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1s.append(train_f1)
    test_f1s.append(test_f1)
    
print("\nAverage AUC over 10 runs:")
print(f"Train AUC: Mean = {np.mean(train_aucs):.4f}, Std = {np.std(train_aucs):.4f}")
print(f"Test AUC:  Mean = {np.mean(test_aucs):.4f}, Std = {np.std(test_aucs):.4f}")
print(f"Train F1: Mean = {np.mean(train_f1s):.4f}, Std = {np.std(train_f1s):.4f}")
print(f"Test F1:  Mean = {np.mean(test_f1s):.4f}, Std = {np.std(test_f1s):.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.3s
# {'n_estimators': 500, 'min_samples_split': 100, 'min_samples_leaf': 300, 'max_features': None, 'max_depth': 250, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.3s
# {'n_estimators': 400, 'min_samples_split': 100, 'min_samples_leaf': 300, 'max_features': None, 'max_depth': 200, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   1.7s
# {'n_estimators': 500, 'min_samples_split': 150, 'min_samples_leaf': 300, 'max_features': None, 'max_depth': 250, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.4s
# {'n_estimators': 400, 'min_samples_split': 50, 'min_samples_leaf': 300, 'max_features': None, 'max_depth': 250, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.3s
# {'n_estimators': 400, 'min_samples_split': 100, 'min_samples_leaf': 300, 'max_features': None, 'max_depth': 250, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# ...
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   1.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   1.9s
# {'n_estimators': 600, 'min_samples_split': 100, 'min_samples_leaf': 300, 'max_features': None, 'max_depth': 250, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   2.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=600; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   1.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=600; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   2.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=600; total time=   1.9s
# {'n_estimators': 500, 'min_samples_split': 50, 'min_samples_leaf': 300, 'max_features': None, 'max_depth': 250, 'class_weight': 'balanced', 'bootstrap': True}
#
# Average AUC over 10 runs:
# Train AUC: Mean = 0.8447, Std = 0.0097
# Test AUC:  Mean = 0.8120, Std = 0.0090
# Train F1: Mean = 0.6794, Std = 0.0127
# Test F1:  Mean = 0.6420, Std = 0.0180

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("LMS Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 4       Mhalo         0.867988  0.020490
# 6       bulge         0.090329  0.030358
# 3      BHMass         0.017127  0.024214
# 5    overdens         0.013417  0.010621
# 2      s_mass         0.006137  0.009350
# 1  avg_s_mass         0.003045  0.005653
# 0   bin_radii         0.001956  0.003343

# %%
low_mass_satellite_df.corr()
# Out:
#                      subID  bin_radii  avg_s_mass  quenching_vector    s_mass  \
# subID             1.000000   0.012483   -0.147451         -0.461102 -0.119578
# bin_radii         0.012483   1.000000   -0.763786         -0.014416  0.008626
# avg_s_mass       -0.147451  -0.763786    1.000000         -0.006994  0.400759
# quenching_vector -0.461102  -0.014416   -0.006994          1.000000 -0.141393
# s_mass           -0.119578   0.008626    0.400759         -0.141393  1.000000
# BHMass           -0.018875   0.006630    0.370520         -0.204118  0.872315
# Mhalo            -0.806539  -0.009713    0.095505          0.447145  0.042330
# overdens         -0.187313  -0.002019    0.053804          0.085638  0.074692
# bulge            -0.168263  -0.004629   -0.040635          0.316598 -0.059694
#
#                     BHMass     Mhalo  overdens     bulge
# subID            -0.018875 -0.806539 -0.187313 -0.168263
# bin_radii         0.006630 -0.009713 -0.002019 -0.004629
# avg_s_mass        0.370520  0.095505  0.053804 -0.040635
# quenching_vector -0.204118  0.447145  0.085638  0.316598
# s_mass            0.872315  0.042330  0.074692 -0.059694
# BHMass            1.000000 -0.039114  0.019820 -0.008716
# Mhalo            -0.039114  1.000000  0.111680  0.193717
# overdens          0.019820  0.111680  1.000000 -0.114078
# bulge            -0.008716  0.193717 -0.114078  1.000000

# %%
train_mean = round(np.mean(train_aucs), 2)
test_mean = round(np.mean(test_aucs), 2)
print(train_mean)
df = pd.DataFrame({
    'Train AUC': [train_mean],
    'Test AUC': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'rf_classification_outputs'
filename = 'lms_rf_quenching_auc.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# 0.84
#    Train AUC  Test AUC
# 0       0.84      0.81
# DataFrame saved to rf_classification_outputs/lms_rf_quenching_auc.csv

# %%
import os
# Define your directory and file name
directory = 'rf_classification_outputs'
filename = 'lms_rf_quenching.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to rf_classification_outputs/lms_rf_quenching.csv

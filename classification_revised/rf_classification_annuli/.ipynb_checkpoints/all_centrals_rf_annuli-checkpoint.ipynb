# %%
import pandas as pd

# %%
low_mass_central_df = pd.read_parquet ('../low_mass_central_df_annuli_revised.parquet')

# %%
# low_mass_central_df

# %%
# # calculating star forming efficiency (SFE) and gas fraction 
# # bin_annuli returns the stellar mass, gas mass, and SFRs in log_10 space
# low_mass_central_df['SFE'] = 10**(low_mass_central_df['avg_SFR'] - low_mass_central_df['avg_gas_mass'])
# low_mass_central_df['f_gas'] = 10**(low_mass_central_df['avg_gas_mass'] - low_mass_central_df['avg_s_mass'])

# %%
high_mass_central_df = pd.read_parquet ('../high_mass_central_df_annuli_revised.parquet')

# %%
# high_mass_central_df

# %%
# # calculating star forming efficiency (SFE) and gas fraction 
# # bin_annuli returns the stellar mass, gas mass, and SFRs in log_10 space
# high_mass_central_df['SFE'] = 10**(high_mass_central_df['avg_SFR'] - high_mass_central_df['avg_gas_mass'])
# high_mass_central_df['f_gas'] = 10**(high_mass_central_df['avg_gas_mass'] - high_mass_central_df['avg_s_mass'])

# %%
all_centrals_df = pd.concat([low_mass_central_df, high_mass_central_df], ignore_index=True)
# all_centrals_df.to_parquet("all_centrals_df_annuli_final_more_feat.parquet", engine="pyarrow")
# all_centrals_df

# %%
# all_centrals_df = pd.read_parquet ('../all_centrals_df_annuli_more_feat.parquet')
# all_centrals_df

# %%
all_centrals_df.isna().any().any()
# Out:
# False

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
all_centrals_df = all_centrals_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "avg_SFR", "avg_gas_mass","gas_mass","Bfld", "veldisp", "BH_AGN"])
all_centrals_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48571    False
# 48572    False
# 48573    False
# 48574    False
# 48575    False
# Length: 48576, dtype: bool

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedGroupKFold


# splitting galaxies into test/train based on subID
unique_galaxies = np.unique(all_centrals_df['subID'])

train_aucs = []
test_aucs = []
feature_importances_list = []
feature_names = None
train_f1s = []
test_f1s = []


for seed in range(10):
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    train_data = all_centrals_df[all_centrals_df['subID'].isin(train_galaxies)]
    test_data = all_centrals_df[all_centrals_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['quenching_vector', 'subID']), train_data['quenching_vector']
    X_test, y_test = test_data.drop(columns=['quenching_vector', 'subID']), test_data['quenching_vector']

    if feature_names is None:
        feature_names = X_train.columns.tolist()
    # scaling
    scaler = RobustScaler()
    X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
    X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

    param_grid = {
    'n_estimators': [500],  
    'max_depth': [10,20,30],  
    'min_samples_split': [50, 100, 200],  
    'min_samples_leaf': [500, 600, 700],   
    'max_features': [None],  
    'bootstrap': [True],
    'class_weight':['balanced']
    }
    rf = RandomForestClassifier(random_state=seed)
    groups_train = train_data['subID']
    cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=seed)

    random_search = RandomizedSearchCV(
    estimator=rf, 
    param_distributions=param_grid, 
    n_iter=10,
    cv=cv, 
    scoring='roc_auc',
    n_jobs=-1,
    random_state=seed,
    verbose=2)

    random_search.fit(X_train_scaled, y_train, groups=groups_train)

    best_rf = random_search.best_estimator_

    y_train_prob = best_rf.predict_proba(X_train_scaled)[:, 1]
    y_test_prob = best_rf.predict_proba(X_test_scaled)[:, 1]

    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
    fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

    # ROC curves
    plt.figure(figsize=(8,6))
    plt.plot(fpr_train, tpr_train, label=f'Train AUC = {roc_auc_score(y_train, y_train_prob):.3f}')
    plt.plot(fpr_test, tpr_test, label=f'Test AUC = {roc_auc_score(y_test, y_test_prob):.3f}')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves')
    plt.legend()
    plt.grid(True)
    plt.show()
    print(random_search.best_params_)

    
    # aucs and feature importance
    train_auc = roc_auc_score(y_train, y_train_prob)
    test_auc = roc_auc_score(y_test, y_test_prob)
    feature_importances_list.append(best_rf.feature_importances_)
    
    train_aucs.append(train_auc)
    test_aucs.append(test_auc)


    y_train_pred = best_rf.predict(X_train_scaled)
    y_test_pred = best_rf.predict(X_test_scaled)

    # f1 scores
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1s.append(train_f1)
    test_f1s.append(test_f1)
    
print("\nAverage AUC over 10 runs:")
print(f"Train AUC: Mean = {np.mean(train_aucs):.4f}, Std = {np.std(train_aucs):.4f}")
print(f"Test AUC:  Mean = {np.mean(test_aucs):.4f}, Std = {np.std(test_aucs):.4f}")
print(f"Train F1: Mean = {np.mean(train_f1s):.4f}, Std = {np.std(train_f1s):.4f}")
print(f"Test F1:  Mean = {np.mean(test_f1s):.4f}, Std = {np.std(test_f1s):.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'n_estimators': 500, 'min_samples_split': 200, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'n_estimators': 500, 'min_samples_split': 50, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 30, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'n_estimators': 500, 'min_samples_split': 50, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.1s
# {'n_estimators': 500, 'min_samples_split': 50, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 30, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  17.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.3s
# {'n_estimators': 500, 'min_samples_split': 50, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'n_estimators': 500, 'min_samples_split': 100, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 30, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'n_estimators': 500, 'min_samples_split': 50, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  17.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  16.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  17.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.6s
# {'n_estimators': 500, 'min_samples_split': 200, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  17.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.4s
# ...
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  17.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  17.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  17.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  17.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  17.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  16.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  16.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  17.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=700, min_samples_split=50, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  17.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  16.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=200, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=700, min_samples_split=100, n_estimators=500; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=20, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=500; total time=  18.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=30, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  16.6s
# {'n_estimators': 500, 'min_samples_split': 50, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'n_estimators': 500, 'min_samples_split': 50, 'min_samples_leaf': 500, 'max_features': None, 'max_depth': 20, 'class_weight': 'balanced', 'bootstrap': True}
#
# Average AUC over 10 runs:
# Train AUC: Mean = 0.8391, Std = 0.0024
# Test AUC:  Mean = 0.8265, Std = 0.0035
# Train F1: Mean = 0.6594, Std = 0.0072
# Test F1:  Mean = 0.6577, Std = 0.0069

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
#     'Bfld': '#EEDD88',
    # 'veldisp': '#EEDD88',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("All Centrals Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 3      BHMass         0.693784  0.017397
# 1  avg_s_mass         0.115092  0.010670
# 6       bulge         0.111890  0.011969
# 2      s_mass         0.025183  0.008231
# 0   bin_radii         0.022943  0.004358
# 5    overdens         0.018867  0.013184
# 4       Mhalo         0.012241  0.004468

# %%
# from sklearn.metrics import f1_score
# y_train_pred = best_rf.predict(X_train_scaled)
# y_test_pred = best_rf.predict(X_test_scaled)

# # f1 scores
# train_f1 = f1_score(y_train, y_train_pred)
# test_f1 = f1_score(y_test, y_test_pred)

# print(f"Train F1 Score: {train_f1:.3f}")
# print(f"Test F1 Score: {test_f1:.3f}")

# %%
import os
# Define your directory and file name
directory = 'rf_classification_outputs'
filename = 'all_centrals_rf_quenching.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to rf_classification_outputs/all_centrals_rf_quenching.csv

# %%
train_mean = round(np.mean(train_aucs), 2)
test_mean = round(np.mean(test_aucs), 2)
print(train_mean)
df = pd.DataFrame({
    'Train AUC': [train_mean],
    'Test AUC': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'rf_classification_outputs'
filename = 'all_centrals_rf_quenching_auc.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# 0.84
#    Train AUC  Test AUC
# 0       0.84      0.83
# DataFrame saved to rf_classification_outputs/all_centrals_rf_quenching_auc.csv

# %%
import pandas as pd

# %%
low_mass_satellite_df = pd.read_parquet ('../low_mass_satellite_df_annuli_more_feat.parquet')

# %%
low_mass_satellite_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 453        42.0   0.127053    8.943308 -0.194197      8.477122
# 454        42.0   0.381159    8.509116 -0.968653      8.303772
# 455        42.0   0.635265    8.209068 -1.759715      7.960976
# 456        42.0   0.889371    7.913028 -1.843849      7.890536
# 457        42.0   1.143477    7.604638 -1.788666      7.883475
# ...         ...        ...         ...       ...           ...
# 54860  593573.0   0.461125    7.915781 -3.874264      7.566107
# 54861  593573.0   0.768541    7.496673 -2.880743      7.366165
# 54862  593573.0   1.075957    7.168706 -3.435107      7.380437
# 54863  593573.0   1.383374    6.925375 -3.566125      7.352052
# 54864  593573.0   1.690790    6.711826 -3.168819      7.341474
#
#        quenching_vector  gas_mass    s_mass    BHMass  class    veldisp  \
# 453                   0       0.0  0.797447  0.001364      1  74.722664
# 454                   0       0.0  0.797447  0.001364      1  74.722664
# 455                   0       0.0  0.797447  0.001364      1  74.722664
# 456                   0       0.0  0.797447  0.001364      1  74.722664
# 457                   0       0.0  0.797447  0.001364      1  74.722664
# ...                 ...       ...       ...       ...    ...        ...
# 54860                 1       0.0  0.146896  0.000124      1  44.716286
# 54861                 0       0.0  0.146896  0.000124      1  44.716286
# 54862                 0       0.0  0.146896  0.000124      1  44.716286
# 54863                 0       0.0  0.146896  0.000124      1  44.716286
# 54864                 0       0.0  0.146896  0.000124      1  44.716286
#
#        global_SFRs  BH_cumQM       BH_cumRM         Mhalo    overdens  \
# 453       1.661067       0.0   0.000000e+00  38878.035156  109.869862
# 454       1.661067       0.0   0.000000e+00  38878.035156  109.869862
# 455       1.661067       0.0   0.000000e+00  38878.035156  109.869862
# 456       1.661067       0.0   0.000000e+00  38878.035156  109.869862
# 457       1.661067       0.0   0.000000e+00  38878.035156  109.869862
# ...            ...       ...            ...           ...         ...
# 54860     0.059573       0.0  1.027657e-321     21.333946    3.807714
# 54861     0.059573       0.0  1.027657e-321     21.333946    3.807714
# 54862     0.059573       0.0  1.027657e-321     21.333946    3.807714
# 54863     0.059573       0.0  1.027657e-321     21.333946    3.807714
# 54864     0.059573       0.0  1.027657e-321     21.333946    3.807714
#
#           bulge      Bfld         BH_AGN
# 453    0.336960  0.355954   0.000000e+00
# 454    0.336960  0.355954   0.000000e+00
# 455    0.336960  0.355954   0.000000e+00
# 456    0.336960  0.355954   0.000000e+00
# 457    0.336960  0.355954   0.000000e+00
# ...         ...       ...            ...
# 54860 -0.010151  0.168837  1.027657e-321
# 54861 -0.010151  0.168837  1.027657e-321
# 54862 -0.010151  0.168837  1.027657e-321
# 54863 -0.010151  0.168837  1.027657e-321
# 54864 -0.010151  0.168837  1.027657e-321
#
# [4258 rows x 19 columns]

# %%
low_mass_satellite_df['quenching_vector'].hist()
# Out:
# <Axes: >

# %%
galaxy_class_counts = low_mass_satellite_df.groupby("subID")["quenching_vector"].nunique()

# count galaxies with only one class vs. two classes
num_single_class_galaxies = (galaxy_class_counts == 1).sum()
num_two_class_galaxies = (galaxy_class_counts > 1).sum()

print(f"Number of galaxies with only one class: {num_single_class_galaxies}")
print(f"Number of galaxies with two classes: {num_two_class_galaxies}")
# Out:
# Number of galaxies with only one class: 408
# Number of galaxies with two classes: 216

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
low_mass_satellite_df = low_mass_satellite_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "avg_SFR","avg_gas_mass", "gas_mass", "Bfld", "veldisp", "BH_AGN"])
low_mass_satellite_df.duplicated()

# X = low_mass_satellite_df.drop(['quenching_vector'], axis=1)
# y = low_mass_satellite_df['quenching_vector']
# Out:
# 453      False
# 454      False
# 455      False
# 456      False
# 457      False
#          ...
# 54860    False
# 54861    False
# 54862    False
# 54863    False
# 54864    False
# Length: 4258, dtype: bool

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score

# splitting galaxies into test/train based on subID
unique_galaxies = np.unique(low_mass_satellite_df['subID'])

train_aucs = []
test_aucs = []
feature_importances_list = []
feature_names = None
train_f1s = []
test_f1s = []


for seed in range(10):
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    train_data = low_mass_satellite_df[low_mass_satellite_df['subID'].isin(train_galaxies)]
    test_data = low_mass_satellite_df[low_mass_satellite_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['quenching_vector', 'subID']), train_data['quenching_vector']
    X_test, y_test = test_data.drop(columns=['quenching_vector', 'subID']), test_data['quenching_vector']

    if feature_names is None:
        feature_names = X_train.columns.tolist()
    # scaling
    scaler = RobustScaler()
    X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
    X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

    xgb_clf = xgb.XGBClassifier(random_state=seed, objective='binary:logistic')

    param_grid_xgb = {
    'n_estimators': [100,150],
    'max_depth': [1],
    'learning_rate': [0.01, 0.05],
    'subsample': [0.8],
    'colsample_bytree': [1.0],
    'min_child_weight': [25,30],
    'gamma': [0.2, 0.4, 0.6],
    'lambda': [4.0, 5.0, 6.0],     # L2 regularization
    'alpha': [4.0, 5.0, 6.0],      # L1 regularization
    'scale_pos_weight': [1.0]    
    }

    random_search_xgb = RandomizedSearchCV(
    estimator=xgb_clf,
    param_distributions=param_grid_xgb,
    n_iter=10,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1, 
    random_state=seed,
    verbose=2,
    )

    random_search_xgb.fit(X_train_scaled, y_train)

    best_xgb = random_search_xgb.best_estimator_

    y_train_prob = best_xgb.predict_proba(X_train_scaled)[:, 1]
    y_test_prob = best_xgb.predict_proba(X_test_scaled)[:, 1]

    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
    fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

    # ROC curves
    plt.figure(figsize=(8,6))
    plt.plot(fpr_train, tpr_train, label=f'Train AUC = {roc_auc_score(y_train, y_train_prob):.3f}')
    plt.plot(fpr_test, tpr_test, label=f'Test AUC = {roc_auc_score(y_test, y_test_prob):.3f}')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # aucs and feature importance
    train_auc = roc_auc_score(y_train, y_train_prob)
    test_auc = roc_auc_score(y_test, y_test_prob)
    feature_importances_list.append(best_xgb.feature_importances_)
    
    train_aucs.append(train_auc)
    test_aucs.append(test_auc)


    y_train_pred = best_xgb.predict(X_train_scaled)
    y_test_pred = best_xgb.predict(X_test_scaled)

    # f1 scores
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1s.append(train_f1)
    test_f1s.append(test_f1)
    
print("\nAverage AUC over 10 runs:")
print(f"Train AUC: Mean = {np.mean(train_aucs):.4f}, Std = {np.std(train_aucs):.4f}")
print(f"Test AUC:  Mean = {np.mean(test_aucs):.4f}, Std = {np.std(test_aucs):.4f}")
print(f"Train F1: Mean = {np.mean(train_f1s):.4f}, Std = {np.std(train_f1s):.4f}")
print(f"Test F1:  Mean = {np.mean(test_f1s):.4f}, Std = {np.std(test_f1s):.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# ...
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.6, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.7, gamma=0.4, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.4, lambda=6.0, learning_rate=0.01, max_depth=1, min_child_weight=30, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.1s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=5.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.6, gamma=0.4, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.7, gamma=0.2, lambda=4.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=4.0, colsample_bytree=0.7, gamma=0.6, lambda=4.0, learning_rate=0.05, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=6.0, colsample_bytree=0.6, gamma=0.6, lambda=5.0, learning_rate=0.01, max_depth=1, min_child_weight=25, n_estimators=100, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# [CV] END alpha=5.0, colsample_bytree=0.6, gamma=0.2, lambda=6.0, learning_rate=0.05, max_depth=1, min_child_weight=30, n_estimators=150, scale_pos_weight=1.0, subsample=0.8; total time=   0.0s
# Average AUC over 10 runs:
# Train AUC: Mean = 0.8412, Std = 0.0181
# Test AUC:  Mean = 0.8342, Std = 0.0153
# Train F1: Mean = 0.6663, Std = 0.1016
# Test F1:  Mean = 0.6723, Std = 0.0753

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("LMS Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 4       Mhalo         0.326661  0.072431
# 3      BHMass         0.208410  0.025088
# 5    overdens         0.206888  0.052585
# 6       bulge         0.130394  0.014623
# 7      BH_AGN         0.127647  0.021451
# 0   bin_radii         0.000000  0.000000
# 1  avg_s_mass         0.000000  0.000000
# 2      s_mass         0.000000  0.000000

# %%
# from sklearn.metrics import f1_score
# y_train_pred = best_rf.predict(X_train_scaled)
# y_test_pred = best_rf.predict(X_test_scaled)

# # f1 scores
# train_f1 = f1_score(y_train, y_train_pred)
# test_f1 = f1_score(y_test, y_test_pred)

# print(f"Train F1 Score: {train_f1:.3f}")
# print(f"Test F1 Score: {test_f1:.3f}")

# %%
low_mass_satellite_df.corr()
# Out:
#                      subID  bin_radii  avg_s_mass  quenching_vector    s_mass  \
# subID             1.000000   0.013471   -0.121309         -0.493961 -0.037939
# bin_radii         0.013471   1.000000   -0.797567         -0.027275  0.009842
# avg_s_mass       -0.121309  -0.797567    1.000000          0.028831  0.344977
# quenching_vector -0.493961  -0.027275    0.028831          1.000000 -0.086160
# s_mass           -0.037939   0.009842    0.344977         -0.086160  1.000000
# BHMass            0.112101   0.008714    0.280462         -0.207856  0.770974
# Mhalo            -0.807528  -0.009388    0.067469          0.463633 -0.029421
# overdens         -0.237542  -0.006726    0.054972          0.197972  0.011574
# bulge            -0.132317  -0.005494   -0.027804          0.278448 -0.099635
# BH_AGN            0.069372   0.000126   -0.011977          0.008576 -0.049649
#
#                     BHMass     Mhalo  overdens     bulge    BH_AGN
# subID             0.112101 -0.807528 -0.237542 -0.132317  0.069372
# bin_radii         0.008714 -0.009388 -0.006726 -0.005494  0.000126
# avg_s_mass        0.280462  0.067469  0.054972 -0.027804 -0.011977
# quenching_vector -0.207856  0.463633  0.197972  0.278448  0.008576
# s_mass            0.770974 -0.029421  0.011574 -0.099635 -0.049649
# BHMass            1.000000 -0.163191 -0.052577 -0.021863 -0.008657
# Mhalo            -0.163191  1.000000  0.186396  0.148077 -0.028916
# overdens         -0.052577  0.186396  1.000000 -0.008573  0.008728
# bulge            -0.021863  0.148077 -0.008573  1.000000  0.013809
# BH_AGN           -0.008657 -0.028916  0.008728  0.013809  1.000000

# %%
low_mass_satellite_df.corr()
# Out:
#                      subID  bin_radii  avg_s_mass  quenching_vector    s_mass  \
# subID             1.000000   0.013471   -0.121309         -0.493961 -0.037939
# bin_radii         0.013471   1.000000   -0.797567         -0.027275  0.009842
# avg_s_mass       -0.121309  -0.797567    1.000000          0.028831  0.344977
# quenching_vector -0.493961  -0.027275    0.028831          1.000000 -0.086160
# s_mass           -0.037939   0.009842    0.344977         -0.086160  1.000000
# BHMass            0.112101   0.008714    0.280462         -0.207856  0.770974
# Mhalo            -0.807528  -0.009388    0.067469          0.463633 -0.029421
# overdens         -0.237542  -0.006726    0.054972          0.197972  0.011574
# bulge            -0.132317  -0.005494   -0.027804          0.278448 -0.099635
# BH_AGN            0.069372   0.000126   -0.011977          0.008576 -0.049649
#
#                     BHMass     Mhalo  overdens     bulge    BH_AGN
# subID             0.112101 -0.807528 -0.237542 -0.132317  0.069372
# bin_radii         0.008714 -0.009388 -0.006726 -0.005494  0.000126
# avg_s_mass        0.280462  0.067469  0.054972 -0.027804 -0.011977
# quenching_vector -0.207856  0.463633  0.197972  0.278448  0.008576
# s_mass            0.770974 -0.029421  0.011574 -0.099635 -0.049649
# BHMass            1.000000 -0.163191 -0.052577 -0.021863 -0.008657
# Mhalo            -0.163191  1.000000  0.186396  0.148077 -0.028916
# overdens         -0.052577  0.186396  1.000000 -0.008573  0.008728
# bulge            -0.021863  0.148077 -0.008573  1.000000  0.013809
# BH_AGN           -0.008657 -0.028916  0.008728  0.013809  1.000000

# %%
import os
# Define your directory and file name
directory = 'xg_classification_outputs'
filename = 'lms_xg_quenching.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to xg_classification_outputs/lms_xg_quenching.csv

# %%
train_mean = round(np.mean(train_aucs), 2)
test_mean = round(np.mean(test_aucs), 2)
print(train_mean)
df = pd.DataFrame({
    'Train AUC': [train_mean],
    'Test AUC': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'xg_classification_outputs'
filename = 'lms_xg_quenching_auc.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# 0.84
#    Train AUC  Test AUC
# 0       0.84      0.83
# DataFrame saved to xg_classification_outputs/lms_xg_quenching_auc.csv

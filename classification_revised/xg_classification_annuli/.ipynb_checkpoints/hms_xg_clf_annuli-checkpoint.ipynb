# %%
import pandas as pd

# %%
high_mass_satellite_df = pd.read_parquet ('../high_mass_satellite_df_annuli_revised.parquet')

# %%
high_mass_satellite_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 91          1.0   0.037018   10.065946 -1.977420      6.628361
# 92          1.0   0.111053    9.816378 -2.138036      6.690369
# 93          1.0   0.185088    9.498950 -2.488943      6.717174
# 94          1.0   0.259123    9.273945 -2.704103      6.806918
# 95          1.0   0.333158    9.124043 -2.386751      7.096273
# ...         ...        ...         ...       ...           ...
# 39101  507459.0   0.973605    7.877430 -4.084393      7.193453
# 39102  507459.0   1.189961    7.721001 -4.255444      7.279958
# 39103  507459.0   1.406318    7.646457 -2.278166      7.301933
# 39104  507459.0   1.622674    7.579882 -3.527098      7.279070
# 39105  507459.0   1.839031    7.530001 -2.649963      7.283091
#
#        quenching_vector     gas_mass     s_mass    BHMass  class    veldisp  \
# 91                    0  5069.831055  55.879173  0.125518      1  333.89325
# 92                    0  5069.831055  55.879173  0.125518      1  333.89325
# 93                    1  5069.831055  55.879173  0.125518      1  333.89325
# 94                    1  5069.831055  55.879173  0.125518      1  333.89325
# 95                    0  5069.831055  55.879173  0.125518      1  333.89325
# ...                 ...          ...        ...       ...    ...        ...
# 39101                 1     0.000000   1.265838  0.001619      1   76.70726
# 39102                 1     0.000000   1.265838  0.001619      1   76.70726
# 39103                 0     0.000000   1.265838  0.001619      1   76.70726
# 39104                 0     0.000000   1.265838  0.001619      1   76.70726
# 39105                 0     0.000000   1.265838  0.001619      1   76.70726
#
#        global_SFRs    BH_cumQM       BH_cumRM         Mhalo     overdens  \
# 91        0.197048  97180768.0  6.904271e-310  38878.035156  8780.408392
# 92        0.197048  97180768.0  6.904271e-310  38878.035156  8780.408392
# 93        0.197048  97180768.0  6.904271e-310  38878.035156  8780.408392
# 94        0.197048  97180768.0  6.904271e-310  38878.035156  8780.408392
# 95        0.197048  97180768.0  6.904271e-310  38878.035156  8780.408392
# ...            ...         ...            ...           ...          ...
# 39101     0.690616         0.0   0.000000e+00     75.038589     2.594790
# 39102     0.690616         0.0   0.000000e+00     75.038589     2.594790
# 39103     0.690616         0.0   0.000000e+00     75.038589     2.594790
# 39104     0.690616         0.0   0.000000e+00     75.038589     2.594790
# 39105     0.690616         0.0   0.000000e+00     75.038589     2.594790
#
#           bulge      Bfld      BH_AGN
# 91     0.508532  0.152681  97180768.0
# 92     0.508532  0.152681  97180768.0
# 93     0.508532  0.152681  97180768.0
# 94     0.508532  0.152681  97180768.0
# 95     0.508532  0.152681  97180768.0
# ...         ...       ...         ...
# 39101 -0.283808  0.148567         0.0
# 39102 -0.283808  0.148567         0.0
# 39103 -0.283808  0.148567         0.0
# 39104 -0.283808  0.148567         0.0
# 39105 -0.283808  0.148567         0.0
#
# [10248 rows x 19 columns]

# %%
high_mass_satellite_df['quenching_vector'].hist()
# Out:
# <Axes: >

# %%
galaxy_class_counts = high_mass_satellite_df.groupby("subID")["quenching_vector"].nunique()

# count galaxies with only one class vs. two classes
num_single_class_galaxies = (galaxy_class_counts == 1).sum()
num_two_class_galaxies = (galaxy_class_counts > 1).sum()

print(f"Number of galaxies with only one class: {num_single_class_galaxies}")
print(f"Number of galaxies with two classes: {num_two_class_galaxies}")
# Out:
# Number of galaxies with only one class: 435
# Number of galaxies with two classes: 534

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
high_mass_satellite_df = high_mass_satellite_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "avg_SFR","avg_gas_mass", "gas_mass", "Bfld", "veldisp", "BH_AGN"])
high_mass_satellite_df.duplicated()
# Out:
# 91       False
# 92       False
# 93       False
# 94       False
# 95       False
#          ...
# 39101    False
# 39102    False
# 39103    False
# 39104    False
# 39105    False
# Length: 10248, dtype: bool

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score

# splitting galaxies into test/train based on subID
unique_galaxies = np.unique(high_mass_satellite_df['subID'])

train_aucs = []
test_aucs = []
feature_importances_list = []
feature_names = None
train_f1s = []
test_f1s = []


for seed in range(10):
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    train_data = high_mass_satellite_df[high_mass_satellite_df['subID'].isin(train_galaxies)]
    test_data = high_mass_satellite_df[high_mass_satellite_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['quenching_vector', 'subID']), train_data['quenching_vector']
    X_test, y_test = test_data.drop(columns=['quenching_vector', 'subID']), test_data['quenching_vector']

    if feature_names is None:
        feature_names = X_train.columns.tolist()
    # scaling
    scaler = RobustScaler()
    X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
    X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

    xgb_clf = xgb.XGBClassifier(random_state=seed, objective='binary:logistic')

    param_grid_xgb = {
    'n_estimators': [600],
    'max_depth': [2],
    'learning_rate': [0.003, 0.005],
    'subsample': [0.6, 0.7],
    'colsample_bytree': [1.0],
    'min_child_weight': [40, 50, 60],
    'gamma': [0.8, 1.0, 1.2],
    'lambda': [7, 8, 9],
    'alpha': [7, 8, 9],
    'scale_pos_weight': [1.0]
}


    random_search_xgb = RandomizedSearchCV(
    estimator=xgb_clf,
    param_distributions=param_grid_xgb,
    n_iter=10,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1, 
    random_state=seed,
    verbose=2,
    )

    random_search_xgb.fit(X_train_scaled, y_train)

    best_xgb = random_search_xgb.best_estimator_

    y_train_prob = best_xgb.predict_proba(X_train_scaled)[:, 1]
    y_test_prob = best_xgb.predict_proba(X_test_scaled)[:, 1]

    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
    fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

    # ROC curves
    plt.figure(figsize=(8,6))
    plt.plot(fpr_train, tpr_train, label=f'Train AUC = {roc_auc_score(y_train, y_train_prob):.3f}')
    plt.plot(fpr_test, tpr_test, label=f'Test AUC = {roc_auc_score(y_test, y_test_prob):.3f}')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # aucs and feature importance
    train_auc = roc_auc_score(y_train, y_train_prob)
    test_auc = roc_auc_score(y_test, y_test_prob)
    feature_importances_list.append(best_xgb.feature_importances_)
    
    train_aucs.append(train_auc)
    test_aucs.append(test_auc)


    y_train_pred = best_xgb.predict(X_train_scaled)
    y_test_pred = best_xgb.predict(X_test_scaled)

    # f1 scores
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1s.append(train_f1)
    test_f1s.append(test_f1)
    
print("\nAverage AUC over 10 runs:")
print(f"Train AUC: Mean = {np.mean(train_aucs):.4f}, Std = {np.std(train_aucs):.4f}")
print(f"Test AUC:  Mean = {np.mean(test_aucs):.4f}, Std = {np.std(test_aucs):.4f}")
print(f"Train F1: Mean = {np.mean(train_f1s):.4f}, Std = {np.std(train_f1s):.4f}")
print(f"Test F1:  Mean = {np.mean(test_f1s):.4f}, Std = {np.std(test_f1s):.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s[CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
#
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.3s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.3s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.3s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.3s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.3s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ...
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s[CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
#
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s[CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
#
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.3s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.2, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=0.8, lambda=8, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s[CV] END alpha=8, colsample_bytree=1.0, gamma=1.0, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=50, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
#
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=8, colsample_bytree=1.0, gamma=1.2, lambda=7, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=9, colsample_bytree=1.0, gamma=1.0, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.6; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=1.2, lambda=9, learning_rate=0.003, max_depth=2, min_child_weight=60, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# [CV] END alpha=7, colsample_bytree=1.0, gamma=0.8, lambda=9, learning_rate=0.005, max_depth=2, min_child_weight=40, n_estimators=600, scale_pos_weight=1.0, subsample=0.7; total time=   0.2s
# Average AUC over 10 runs:
# Train AUC: Mean = 0.8548, Std = 0.0067
# Test AUC:  Mean = 0.8196, Std = 0.0059
# Train F1: Mean = 0.7676, Std = 0.0079
# Test F1:  Mean = 0.7328, Std = 0.0109

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("HMS Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 6       bulge         0.292866  0.061062
# 3      BHMass         0.171078  0.054656
# 1  avg_s_mass         0.132942  0.011120
# 2      s_mass         0.121414  0.033229
# 4       Mhalo         0.120375  0.023333
# 0   bin_radii         0.098743  0.020019
# 5    overdens         0.062582  0.049998

# %%
import os
# Define your directory and file name
directory = 'xg_classification_outputs'
filename = 'hms_xg_quenching.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to xg_classification_outputs/hms_xg_quenching.csv

# %%
train_mean = round(np.mean(train_aucs), 2)
test_mean = round(np.mean(test_aucs), 2)
print(train_mean)
df = pd.DataFrame({
    'Train AUC': [train_mean],
    'Test AUC': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'xg_classification_outputs'
filename = 'hms_xg_quenching_auc.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# 0.85
#    Train AUC  Test AUC
# 0       0.85      0.82
# DataFrame saved to xg_classification_outputs/hms_xg_quenching_auc.csv

# %%
import pandas as pd
import numpy as np

# %%
high_mass_central_df = pd.read_parquet ('../high_mass_central_df_annuli_revised.parquet')

# %%
high_mass_central_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 0           0.0   0.010883   10.939674 -1.120602      7.966769
# 1           0.0   0.032649   10.494615 -1.556470      7.919378
# 2           0.0   0.054415    9.982732 -2.017950      7.934402
# 3           0.0   0.076182    9.739688 -2.263846      7.927703
# 4           0.0   0.097948    9.594884 -2.389380      7.926022
# ...         ...        ...         ...       ...           ...
# 54984  594444.0   0.169860    9.321200 -2.636930      6.265163
# 54985  594444.0   0.509579    8.999712 -1.776677      6.709038
# 54986  594444.0   0.849298    8.734355 -3.316755      7.059817
# 54987  594444.0   1.189017    8.498129 -3.504491      6.857232
# 54988  594444.0   1.528736    8.287459 -3.689198      6.383893
#
#        quenching_vector      gas_mass      s_mass    BHMass  class  \
# 0                     0  19187.548828  370.558472  0.700941      0
# 1                     0  19187.548828  370.558472  0.700941      0
# 2                     0  19187.548828  370.558472  0.700941      0
# 3                     1  19187.548828  370.558472  0.700941      0
# 4                     1  19187.548828  370.558472  0.700941      0
# ...                 ...           ...         ...       ...    ...
# 54984                 1      0.000000    2.942021  0.006637      0
# 54985                 0      0.000000    2.942021  0.006637      0
# 54986                 1      0.000000    2.942021  0.006637      0
# 54987                 1      0.000000    2.942021  0.006637      0
# 54988                 1      0.000000    2.942021  0.006637      0
#
#           veldisp  global_SFRs      BH_cumQM       BH_cumRM         Mhalo  \
# 0      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 1      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 2      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 3      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 4      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# ...           ...          ...           ...            ...           ...
# 54984   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54985   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54986   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54987   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
# 54988   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
#
#             overdens     bulge      Bfld        BH_AGN
# 0      102677.912949  0.982283  0.205462  5.678228e+08
# 1      102677.912949  0.982283  0.205462  5.678228e+08
# 2      102677.912949  0.982283  0.205462  5.678228e+08
# 3      102677.912949  0.982283  0.205462  5.678228e+08
# 4      102677.912949  0.982283  0.205462  5.678228e+08
# ...              ...       ...       ...           ...
# 54984      19.981537 -0.021362  0.070190  2.062991e+04
# 54985      19.981537 -0.021362  0.070190  2.062991e+04
# 54986      19.981537 -0.021362  0.070190  2.062991e+04
# 54987      19.981537 -0.021362  0.070190  2.062991e+04
# 54988      19.981537 -0.021362  0.070190  2.062991e+04
#
# [26899 rows x 19 columns]

# %%
# # calculating star forming efficiency (SFE) and gas fraction 
# low_mass_satellite_df['SFE'] = 10**(low_mass_satellite_df['avg_SFR'] - low_mass_satellite_df['avg_gas_mass'])
# low_mass_satellite_df['f_gas'] = 10**(low_mass_satellite_df['avg_gas_mass'] - low_mass_satellite_df['avg_s_mass'])

# %%
# # remove the rows where the sfr_indicator is 0.0 -> implies artificially imposed minimum
# low_mass_satellite_df = low_mass_satellite_df[low_mass_satellite_df['sfr_indicator'] != 0.0]
# low_mass_satellite_df

# %%
# star forming quenching vector value = 0
high_mass_central_df = high_mass_central_df[high_mass_central_df['quenching_vector'] != 1]
high_mass_central_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 0           0.0   0.010883   10.939674 -1.120602      7.966769
# 1           0.0   0.032649   10.494615 -1.556470      7.919378
# 2           0.0   0.054415    9.982732 -2.017950      7.934402
# 644     17185.0   0.004284   10.488805 -1.521891      7.630356
# 645     17185.0   0.012853   10.220413 -1.775405      7.611776
# ...         ...        ...         ...       ...           ...
# 48949  562410.0   1.119661    8.413935 -1.564219      7.630833
# 48950  562410.0   1.439564    8.239394 -2.031924      7.606252
# 48951  562410.0   1.759467    7.978919 -2.663112      7.356964
# 49066  563241.0   0.172311    9.596712 -2.317702      7.677955
# 54985  594444.0   0.509579    8.999712 -1.776677      6.709038
#
#        quenching_vector      gas_mass      s_mass    BHMass  class  \
# 0                     0  19187.548828  370.558472  0.700941      0
# 1                     0  19187.548828  370.558472  0.700941      0
# 2                     0  19187.548828  370.558472  0.700941      0
# 644                   0      0.000000  228.544006  0.556990      0
# 645                   0      0.000000  228.544006  0.556990      0
# ...                 ...           ...         ...       ...    ...
# 48949                 0      0.000000    2.275262  0.004635      0
# 48950                 0      0.000000    2.275262  0.004635      0
# 48951                 0      0.000000    2.275262  0.004635      0
# 49066                 0      0.212526    2.357653  0.008387      0
# 54985                 0      0.000000    2.942021  0.006637      0
#
#           veldisp  global_SFRs      BH_cumQM       BH_cumRM         Mhalo  \
# 0      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 1      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 2      603.875061     0.456323  5.678228e+08  6.904271e-310  38878.035156
# 644    594.971252     1.667390  1.161822e+09   3.915732e+08  33180.992188
# 645    594.971252     1.667390  1.161822e+09   3.915732e+08  33180.992188
# ...           ...          ...           ...            ...           ...
# 48949   82.065796     1.607175  2.461513e+03  1.389233e-316     34.545956
# 48950   82.065796     1.607175  2.461513e+03  1.389233e-316     34.545956
# 48951   82.065796     1.607175  2.461513e+03  1.389233e-316     34.545956
# 49066   82.442406     0.016811  5.532517e+05   0.000000e+00     38.519566
# 54985   89.968681     0.066943  2.062991e+04   0.000000e+00     19.274660
#
#             overdens     bulge      Bfld        BH_AGN
# 0      102677.912949  0.982283  0.205462  5.678228e+08
# 1      102677.912949  0.982283  0.205462  5.678228e+08
# 2      102677.912949  0.982283  0.205462  5.678228e+08
# 644      4603.822492  1.289787  0.244981  1.553395e+09
# 645      4603.822492  1.289787  0.244981  1.553395e+09
# ...              ...       ...       ...           ...
# 48949       4.056387 -0.793238  0.072292  2.461513e+03
# 48950       4.056387 -0.793238  0.072292  2.461513e+03
# 48951       4.056387 -0.793238  0.072292  2.461513e+03
# 49066      54.214864  0.083967  0.068477  5.532517e+05
# 54985      19.981537 -0.021362  0.070190  2.062991e+04
#
# [14646 rows x 19 columns]

# %%
high_mass_central_df.shape
# Out:
# (14646, 19)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
high_mass_central_df = high_mass_central_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "gas_mass","avg_gas_mass", "quenching_vector", "Bfld", "veldisp", "BH_AGN"])

# %%
high_mass_central_df['avg_SFR'].hist()
# Out:
# <Axes: >

# %%
# this indicates that there are more instances of the delta rate on the left

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

galaxy_ids = high_mass_central_df['subID']

feature_importances_list = []
feature_names = None
test_mses = []
train_mses = []


for seed in range(10):
    # split galaxies into 50% training and 50% testing
    unique_galaxies = np.unique(high_mass_central_df['subID'])
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    # assign spaxels based on galaxy split
    train_data = high_mass_central_df[high_mass_central_df['subID'].isin(train_galaxies)]
    test_data = high_mass_central_df[high_mass_central_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['avg_SFR', 'subID']), train_data['avg_SFR']
    X_test, y_test = test_data.drop(columns=['avg_SFR', 'subID']), test_data['avg_SFR']
    
    
    if feature_names is None:
        feature_names = X_train.columns.tolist()

    scaler = RobustScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    param_grid = {
    'n_estimators': [100,200, 300, 400, 500],  
    'max_depth': [50, 100, 150, 200, 250],  
    'min_samples_split': [100, 200, 300, 400],  
    'min_samples_leaf': [300, 400, 500, 600],  
    'max_features': [None], 
    'bootstrap': [True],
    }
    rf_regressor = RandomForestRegressor(random_state=seed, n_jobs=-1)
    cv = KFold(n_splits=5, shuffle=True, random_state=seed)

    random_search = RandomizedSearchCV(
    estimator=rf_regressor, 
    param_distributions=param_grid, 
    n_iter=10,
    cv=cv, 
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    random_state=seed,
    verbose=2)

    random_search.fit(X_train_scaled, y_train)

    best_rf_regressor = random_search.best_estimator_

    best_rf_regressor.fit(X_train_scaled, y_train)
    
    y_train_pred = best_rf_regressor.predict(X_train_scaled)
    y_test_pred = best_rf_regressor.predict(X_test_scaled)
    
    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)
    
    train_mses.append(train_mse)
    test_mses.append(test_mse)
    
    feature_importances_list.append(best_rf_regressor.feature_importances_)
#     print(random_search.best_params_)
    print(f"Run {seed+1}: Train MSE = {train_mse:.4f}, Test MSE = {test_mse:.4f}")

print("\nAverage MSE over 10 runs:")
print(f"Train MSE: Mean = {np.mean(train_mses):.4f}, Std = {np.std(train_mses):.4f}")
print(f"Test MSE:  Mean = {np.mean(test_mses):.4f}, Std = {np.std(test_mses):.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=   2.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=   3.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=   3.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=   3.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=500; total time=   3.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=500; total time=   3.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=500; total time=   3.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=500; total time=   3.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=500; total time=   3.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=500; total time=   1.6s
# Run 1: Train MSE = 0.2598, Test MSE = 0.2877
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=500; total time=   4.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=500; total time=   4.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=500; total time=   4.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=500; total time=   4.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=500; total time=   4.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=300; total time=   2.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=300; total time=   2.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   3.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   3.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   3.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   4.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=   3.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=   3.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   4.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=   3.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=   2.1s
# Run 2: Train MSE = 0.2563, Test MSE = 0.2881
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=500; total time=   4.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=500; total time=   4.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=500; total time=   4.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=500; total time=   4.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=500; total time=   4.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=300; total time=   1.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=300; total time=   1.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=300; total time=   1.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=300; total time=   1.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   3.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   3.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   4.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   3.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=   3.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=500; total time=   3.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=   3.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=   3.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=   2.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=   3.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=200; total time=   0.8s
# Run 3: Train MSE = 0.2606, Test MSE = 0.2778
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.5s
# Run 4: Train MSE = 0.2604, Test MSE = 0.3017
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   3.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   3.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   3.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   4.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   3.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=300, n_estimators=300; total time=   1.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=300, n_estimators=300; total time=   1.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=300, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=300, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=300, n_estimators=300; total time=   1.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=500; total time=   3.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=500; total time=   3.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=500; total time=   4.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=500; total time=   3.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=500; total time=   3.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=100; total time=   0.4s
# Run 5: Train MSE = 0.2745, Test MSE = 0.2659
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   2.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   2.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   3.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   2.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=400, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   2.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   2.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   2.1s
# Run 6: Train MSE = 0.2558, Test MSE = 0.2852
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   2.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=300, n_estimators=400; total time=   3.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.3s
# ...
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   4.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   4.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   4.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   4.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   1.4s
# Run 8: Train MSE = 0.2586, Test MSE = 0.2783
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=400; total time=   2.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=400; total time=   2.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   1.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=400; total time=   2.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=300, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=200, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=400, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   4.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   4.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   4.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   4.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   3.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=200; total time=   0.8s
# Run 9: Train MSE = 0.2564, Test MSE = 0.2962
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=300; total time=   2.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=300, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=300; total time=   2.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=200, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   2.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   1.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   2.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=400, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   3.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=200, n_estimators=400; total time=   3.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=400, n_estimators=200; total time=   0.7s
# Run 10: Train MSE = 0.2612, Test MSE = 0.2843
#
# Average MSE over 10 runs:
# Train MSE: Mean = 0.2599, Std = 0.0053
# Test MSE:  Mean = 0.2859, Std = 0.0098

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("HMC Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 1  avg_s_mass         0.576955  0.022214
# 6       bulge         0.210448  0.029974
# 3      BHMass         0.187578  0.021069
# 2      s_mass         0.009086  0.006333
# 5    overdens         0.005735  0.013577
# 4       Mhalo         0.005422  0.006726
# 0   bin_radii         0.004776  0.004827

# %%
import os
# Define your directory and file name
directory = 'rf_regression_outputs'
filename = 'hmc_rf_reg.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to rf_regression_outputs/hmc_rf_reg.csv

# %%
train_mean = round(np.mean(train_mses), 2)
test_mean = round(np.mean(test_mses), 2)

df = pd.DataFrame({
    'Train MSE': [train_mean],
    'Test MSE': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'rf_regression_outputs'
filename = 'hmc_rf_reg_mse.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
#    Train MSE  Test MSE
# 0       0.26      0.29
# DataFrame saved to rf_regression_outputs/hmc_rf_reg_mse.csv

# %%
import pandas as pd
import numpy as np

# %%
# low_mass_satellite_df = pd.read_parquet ('low_mass_satellite_df.parquet')
low_mass_satellite_df = pd.read_parquet ('../low_mass_satellite_df_annuli_revised.parquet')

# %%
low_mass_satellite_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 439        37.0   0.174505    8.905776 -0.052619      8.682093
# 440        37.0   0.523516    8.636583 -0.643683      8.302815
# 441        37.0   0.872526    8.421218 -1.414926      7.867777
# 442        37.0   1.221537    8.243556 -1.699316      7.714798
# 443        37.0   1.570547    8.094305 -1.657207      7.711024
# ...         ...        ...         ...       ...           ...
# 54860  593573.0   0.461125    7.915781 -3.874264      7.566107
# 54861  593573.0   0.768541    7.496673 -2.880743      7.366165
# 54862  593573.0   1.075957    7.168706 -3.435107      7.380437
# 54863  593573.0   1.383374    6.925375 -3.566125      7.352052
# 54864  593573.0   1.690790    6.711826 -3.168819      7.341474
#
#        quenching_vector  gas_mass    s_mass    BHMass  class    veldisp  \
# 439                   0  0.022175  1.336990  0.003621      1  77.483803
# 440                   0  0.022175  1.336990  0.003621      1  77.483803
# 441                   0  0.022175  1.336990  0.003621      1  77.483803
# 442                   0  0.022175  1.336990  0.003621      1  77.483803
# 443                   0  0.022175  1.336990  0.003621      1  77.483803
# ...                 ...       ...       ...       ...    ...        ...
# 54860                 1  0.000000  0.146896  0.000124      1  44.716286
# 54861                 0  0.000000  0.146896  0.000124      1  44.716286
# 54862                 0  0.000000  0.146896  0.000124      1  44.716286
# 54863                 0  0.000000  0.146896  0.000124      1  44.716286
# 54864                 0  0.000000  0.146896  0.000124      1  44.716286
#
#        global_SFRs     BH_cumQM       BH_cumRM         Mhalo    overdens  \
# 439       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 440       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 441       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 442       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 443       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# ...            ...          ...            ...           ...         ...
# 54860     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54861     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54862     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54863     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54864     0.059573     0.000000  1.027657e-321     21.333946    3.807714
#
#           bulge      Bfld         BH_AGN
# 439   -0.682291  0.694089   8.761890e+03
# 440   -0.682291  0.694089   8.761890e+03
# 441   -0.682291  0.694089   8.761890e+03
# 442   -0.682291  0.694089   8.761890e+03
# 443   -0.682291  0.694089   8.761890e+03
# ...         ...       ...            ...
# 54860 -0.044053  0.168837  1.027657e-321
# 54861 -0.044053  0.168837  1.027657e-321
# 54862 -0.044053  0.168837  1.027657e-321
# 54863 -0.044053  0.168837  1.027657e-321
# 54864 -0.044053  0.168837  1.027657e-321
#
# [5831 rows x 19 columns]

# %%
# # calculating star forming efficiency (SFE) and gas fraction 
# low_mass_satellite_df['SFE'] = 10**(low_mass_satellite_df['avg_SFR'] - low_mass_satellite_df['avg_gas_mass'])
# low_mass_satellite_df['f_gas'] = 10**(low_mass_satellite_df['avg_gas_mass'] - low_mass_satellite_df['avg_s_mass'])

# %%
# # remove the rows where the sfr_indicator is 0.0 -> implies artificially imposed minimum
# low_mass_satellite_df = low_mass_satellite_df[low_mass_satellite_df['sfr_indicator'] != 0.0]
# low_mass_satellite_df

# %%
# star forming quenching vector value = 0
low_mass_satellite_df = low_mass_satellite_df[low_mass_satellite_df['quenching_vector'] != 1]
low_mass_satellite_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 439        37.0   0.174505    8.905776 -0.052619      8.682093
# 440        37.0   0.523516    8.636583 -0.643683      8.302815
# 441        37.0   0.872526    8.421218 -1.414926      7.867777
# 442        37.0   1.221537    8.243556 -1.699316      7.714798
# 443        37.0   1.570547    8.094305 -1.657207      7.711024
# ...         ...        ...         ...       ...           ...
# 54859  593573.0   0.153708    8.272140 -1.878263      7.835258
# 54861  593573.0   0.768541    7.496673 -2.880743      7.366165
# 54862  593573.0   1.075957    7.168706 -3.435107      7.380437
# 54863  593573.0   1.383374    6.925375 -3.566125      7.352052
# 54864  593573.0   1.690790    6.711826 -3.168819      7.341474
#
#        quenching_vector  gas_mass    s_mass    BHMass  class    veldisp  \
# 439                   0  0.022175  1.336990  0.003621      1  77.483803
# 440                   0  0.022175  1.336990  0.003621      1  77.483803
# 441                   0  0.022175  1.336990  0.003621      1  77.483803
# 442                   0  0.022175  1.336990  0.003621      1  77.483803
# 443                   0  0.022175  1.336990  0.003621      1  77.483803
# ...                 ...       ...       ...       ...    ...        ...
# 54859                 0  0.000000  0.146896  0.000124      1  44.716286
# 54861                 0  0.000000  0.146896  0.000124      1  44.716286
# 54862                 0  0.000000  0.146896  0.000124      1  44.716286
# 54863                 0  0.000000  0.146896  0.000124      1  44.716286
# 54864                 0  0.000000  0.146896  0.000124      1  44.716286
#
#        global_SFRs     BH_cumQM       BH_cumRM         Mhalo    overdens  \
# 439       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 440       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 441       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 442       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# 443       2.468716  8761.889648   0.000000e+00  38878.035156  202.795135
# ...            ...          ...            ...           ...         ...
# 54859     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54861     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54862     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54863     0.059573     0.000000  1.027657e-321     21.333946    3.807714
# 54864     0.059573     0.000000  1.027657e-321     21.333946    3.807714
#
#           bulge      Bfld         BH_AGN
# 439   -0.682291  0.694089   8.761890e+03
# 440   -0.682291  0.694089   8.761890e+03
# 441   -0.682291  0.694089   8.761890e+03
# 442   -0.682291  0.694089   8.761890e+03
# 443   -0.682291  0.694089   8.761890e+03
# ...         ...       ...            ...
# 54859 -0.044053  0.168837  1.027657e-321
# 54861 -0.044053  0.168837  1.027657e-321
# 54862 -0.044053  0.168837  1.027657e-321
# 54863 -0.044053  0.168837  1.027657e-321
# 54864 -0.044053  0.168837  1.027657e-321
#
# [3964 rows x 19 columns]

# %%
low_mass_satellite_df.shape
# Out:
# (3964, 19)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
low_mass_satellite_df = low_mass_satellite_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "gas_mass","avg_gas_mass", "quenching_vector", "Bfld", "veldisp", "BH_AGN"])

# X = low_mass_satellite_df.drop(['f_gas'], axis=1)
# y = low_mass_satellite_df['f_gas']

# %%
low_mass_satellite_df['avg_SFR'].hist()
# Out:
# <Axes: >

# %%
# this indicates that there are more instances of the delta rate on the left

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

galaxy_ids = low_mass_satellite_df['subID']

feature_importances_list = []
feature_names = None
test_mses = []
train_mses = []


for seed in range(10):
    # split galaxies into 50% training and 50% testing
    unique_galaxies = np.unique(low_mass_satellite_df['subID'])
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    # assign spaxels based on galaxy split
    train_data = low_mass_satellite_df[low_mass_satellite_df['subID'].isin(train_galaxies)]
    test_data = low_mass_satellite_df[low_mass_satellite_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['avg_SFR', 'subID']), train_data['avg_SFR']
    X_test, y_test = test_data.drop(columns=['avg_SFR', 'subID']), test_data['avg_SFR']
    
    
    if feature_names is None:
        feature_names = X_train.columns.tolist()

    scaler = RobustScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    param_grid = {
    'n_estimators': [100,200, 300, 400, 500],  
    'max_depth': [50, 100, 150, 200, 250],  
    'min_samples_split': [50, 100, 150],  
    'min_samples_leaf': [100, 200, 300, 400],  
    'max_features': [None], 
    'bootstrap': [True],
    }
    rf_regressor = RandomForestRegressor(random_state=seed, n_jobs=-1)
    cv = KFold(n_splits=5, shuffle=True, random_state=seed)

    random_search = RandomizedSearchCV(
    estimator=rf_regressor, 
    param_distributions=param_grid, 
    n_iter=10,
    cv=cv, 
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    random_state=seed,
    verbose=2)

    random_search.fit(X_train_scaled, y_train)

    best_rf_regressor = random_search.best_estimator_

    best_rf_regressor.fit(X_train_scaled, y_train)
    
    y_train_pred = best_rf_regressor.predict(X_train_scaled)
    y_test_pred = best_rf_regressor.predict(X_test_scaled)
    
    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)
    
    train_mses.append(train_mse)
    test_mses.append(test_mse)
    
    feature_importances_list.append(best_rf_regressor.feature_importances_)
#     print(random_search.best_params_)
    print(f"Run {seed+1}: Train MSE = {train_mse:.4f}, Test MSE = {test_mse:.4f}")

print("\nAverage MSE over 10 runs:")
print(f"Train MSE: Mean = {np.mean(train_mses):.4f}, Std = {np.std(train_mses):.4f}")
print(f"Test MSE:  Mean = {np.mean(test_mses):.4f}, Std = {np.std(test_mses):.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=   0.6s
# Run 1: Train MSE = 0.2685, Test MSE = 0.2903
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=300; total time=   0.5s
# Run 2: Train MSE = 0.2587, Test MSE = 0.3022
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.4s
# Run 3: Train MSE = 0.2789, Test MSE = 0.2788
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.5s
# Run 4: Train MSE = 0.2636, Test MSE = 0.2960
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.6s
# Run 5: Train MSE = 0.2775, Test MSE = 0.2849
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=400; total time=   0.7s
# Run 6: Train MSE = 0.2675, Test MSE = 0.2908
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=50, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=300; total time=   0.7s
# ...
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.5s
# Run 8: Train MSE = 0.2853, Test MSE = 0.2672
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=100, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=100, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   0.8s
# Run 9: Train MSE = 0.2701, Test MSE = 0.2885
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   0.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=150, n_estimators=400; total time=   1.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=100, min_samples_split=50, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=200, min_samples_split=150, n_estimators=500; total time=   0.7s
# Run 10: Train MSE = 0.2661, Test MSE = 0.2860
#
# Average MSE over 10 runs:
# Train MSE: Mean = 0.2709, Std = 0.0075
# Test MSE:  Mean = 0.2869, Std = 0.0090

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
    # 'Bfld': '#EEDD88',
    # 'veldisp': '#CC3311',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("LMS Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 1  avg_s_mass         0.924536  0.009521
# 6       bulge         0.045667  0.009903
# 0   bin_radii         0.012852  0.005859
# 4       Mhalo         0.004828  0.003425
# 5    overdens         0.004437  0.004390
# 3      BHMass         0.004223  0.001177
# 2      s_mass         0.003457  0.001767

# %%
low_mass_satellite_df.corr()
# Out:
#                subID  bin_radii  avg_s_mass   avg_SFR    s_mass    BHMass  \
# subID       1.000000   0.028881   -0.149387 -0.110800 -0.240204 -0.192119
# bin_radii   0.028881   1.000000   -0.793152 -0.517114 -0.013869 -0.016820
# avg_s_mass -0.149387  -0.793152    1.000000  0.693531  0.389333  0.390791
# avg_SFR    -0.110800  -0.517114    0.693531  1.000000  0.274866  0.267223
# s_mass     -0.240204  -0.013869    0.389333  0.274866  1.000000  0.895213
# BHMass     -0.192119  -0.016820    0.390791  0.267223  0.895213  1.000000
# Mhalo      -0.729958  -0.023238    0.091716  0.056873  0.105510  0.093729
# overdens   -0.194620  -0.000882    0.058867  0.091244  0.145470  0.079162
# bulge       0.067103  -0.033331   -0.095044 -0.194201 -0.119195 -0.002113
#
#                Mhalo  overdens     bulge
# subID      -0.729958 -0.194620  0.067103
# bin_radii  -0.023238 -0.000882 -0.033331
# avg_s_mass  0.091716  0.058867 -0.095044
# avg_SFR     0.056873  0.091244 -0.194201
# s_mass      0.105510  0.145470 -0.119195
# BHMass      0.093729  0.079162 -0.002113
# Mhalo       1.000000  0.098455 -0.026732
# overdens    0.098455  1.000000 -0.184553
# bulge      -0.026732 -0.184553  1.000000

# %%
import os
# Define your directory and file name
directory = 'rf_regression_outputs'
filename = 'lms_rf_reg.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to rf_regression_outputs/lms_rf_reg.csv

# %%
train_mean = round(np.mean(train_mses), 2)
test_mean = round(np.mean(test_mses), 2)

df = pd.DataFrame({
    'Train MSE': [train_mean],
    'Test MSE': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'rf_regression_outputs'
filename = 'lms_rf_reg_mse.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
#    Train MSE  Test MSE
# 0       0.27      0.29
# DataFrame saved to rf_regression_outputs/lms_rf_reg_mse.csv

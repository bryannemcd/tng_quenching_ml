# %%
import pandas as pd
import numpy as np

# %%
low_mass_central_df = pd.read_parquet ('../low_mass_central_df_annuli_revised.parquet')

# %%
high_mass_central_df = pd.read_parquet ('../high_mass_central_df_annuli_revised.parquet')

# %%
all_centrals_df = pd.concat([low_mass_central_df, high_mass_central_df], ignore_index=True)

# %%
all_centrals_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 0      312415.0   0.071176    8.105450 -3.995854      7.655353
# 1      312415.0   0.213527    8.175151 -3.359508      7.247262
# 2      312415.0   0.355879    7.912692 -2.209567      6.888073
# 3      312415.0   0.498230    7.599713 -4.369588      6.704756
# 4      312415.0   0.640582    7.371823 -4.605686      6.710869
# ...         ...        ...         ...       ...           ...
# 48571  594444.0   0.169860    9.321200 -2.636930      6.265163
# 48572  594444.0   0.509579    8.999712 -1.776677      6.709038
# 48573  594444.0   0.849298    8.734355 -3.316755      7.059817
# 48574  594444.0   1.189017    8.498129 -3.504491      6.857232
# 48575  594444.0   1.528736    8.287459 -3.689198      6.383893
#
#        quenching_vector  gas_mass    s_mass    BHMass  class    veldisp  \
# 0                     1       0.0  0.509563  0.001050      0  64.871277
# 1                     0       0.0  0.509563  0.001050      0  64.871277
# 2                     0       0.0  0.509563  0.001050      0  64.871277
# 3                     1       0.0  0.509563  0.001050      0  64.871277
# 4                     1       0.0  0.509563  0.001050      0  64.871277
# ...                 ...       ...       ...       ...    ...        ...
# 48571                 1       0.0  2.942021  0.006637      0  89.968681
# 48572                 0       0.0  2.942021  0.006637      0  89.968681
# 48573                 1       0.0  2.942021  0.006637      0  89.968681
# 48574                 1       0.0  2.942021  0.006637      0  89.968681
# 48575                 1       0.0  2.942021  0.006637      0  89.968681
#
#        global_SFRs     BH_cumQM       BH_cumRM      Mhalo   overdens  \
# 0         0.295028      0.00000  9.881313e-324  980.83374  45.328607
# 1         0.295028      0.00000  9.881313e-324  980.83374  45.328607
# 2         0.295028      0.00000  9.881313e-324  980.83374  45.328607
# 3         0.295028      0.00000  9.881313e-324  980.83374  45.328607
# 4         0.295028      0.00000  9.881313e-324  980.83374  45.328607
# ...            ...          ...            ...        ...        ...
# 48571     0.066943  20629.90625   0.000000e+00   19.27466  19.981537
# 48572     0.066943  20629.90625   0.000000e+00   19.27466  19.981537
# 48573     0.066943  20629.90625   0.000000e+00   19.27466  19.981537
# 48574     0.066943  20629.90625   0.000000e+00   19.27466  19.981537
# 48575     0.066943  20629.90625   0.000000e+00   19.27466  19.981537
#
#           bulge     Bfld         BH_AGN
# 0      0.155899  0.12591  9.881313e-324
# 1      0.155899  0.12591  9.881313e-324
# 2      0.155899  0.12591  9.881313e-324
# 3      0.155899  0.12591  9.881313e-324
# 4      0.155899  0.12591  9.881313e-324
# ...         ...      ...            ...
# 48571 -0.021362  0.07019   2.062991e+04
# 48572 -0.021362  0.07019   2.062991e+04
# 48573 -0.021362  0.07019   2.062991e+04
# 48574 -0.021362  0.07019   2.062991e+04
# 48575 -0.021362  0.07019   2.062991e+04
#
# [48576 rows x 19 columns]

# %%
# # calculating star forming efficiency (SFE) and gas fraction 
# low_mass_satellite_df['SFE'] = 10**(low_mass_satellite_df['avg_SFR'] - low_mass_satellite_df['avg_gas_mass'])
# low_mass_satellite_df['f_gas'] = 10**(low_mass_satellite_df['avg_gas_mass'] - low_mass_satellite_df['avg_s_mass'])

# %%
# # remove the rows where the sfr_indicator is 0.0 -> implies artificially imposed minimum
# low_mass_satellite_df = low_mass_satellite_df[low_mass_satellite_df['sfr_indicator'] != 0.0]
# low_mass_satellite_df

# %%
# star forming quenching vector value = 0
all_centrals_df = all_centrals_df[all_centrals_df['quenching_vector'] != 1]
all_centrals_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 1      312415.0   0.213527    8.175151 -3.359508      7.247262
# 2      312415.0   0.355879    7.912692 -2.209567      6.888073
# 6      312415.0   0.925285    7.054781 -4.070769      6.963181
# 7      312415.0   1.067636    6.900457 -3.289078      7.173378
# 8      312415.0   1.209988    6.796739 -2.832557      7.367570
# ...         ...        ...         ...       ...           ...
# 48563  562410.0   1.119661    8.413935 -1.564219      7.630833
# 48564  562410.0   1.439564    8.239394 -2.031924      7.606252
# 48565  562410.0   1.759467    7.978919 -2.663112      7.356964
# 48566  563241.0   0.172311    9.596712 -2.317702      7.677955
# 48572  594444.0   0.509579    8.999712 -1.776677      6.709038
#
#        quenching_vector  gas_mass    s_mass    BHMass  class    veldisp  \
# 1                     0  0.000000  0.509563  0.001050      0  64.871277
# 2                     0  0.000000  0.509563  0.001050      0  64.871277
# 6                     0  0.000000  0.509563  0.001050      0  64.871277
# 7                     0  0.000000  0.509563  0.001050      0  64.871277
# 8                     0  0.000000  0.509563  0.001050      0  64.871277
# ...                 ...       ...       ...       ...    ...        ...
# 48563                 0  0.000000  2.275262  0.004635      0  82.065796
# 48564                 0  0.000000  2.275262  0.004635      0  82.065796
# 48565                 0  0.000000  2.275262  0.004635      0  82.065796
# 48566                 0  0.212526  2.357653  0.008387      0  82.442406
# 48572                 0  0.000000  2.942021  0.006637      0  89.968681
#
#        global_SFRs       BH_cumQM       BH_cumRM       Mhalo   overdens  \
# 1         0.295028       0.000000  9.881313e-324  980.833740  45.328607
# 2         0.295028       0.000000  9.881313e-324  980.833740  45.328607
# 6         0.295028       0.000000  9.881313e-324  980.833740  45.328607
# 7         0.295028       0.000000  9.881313e-324  980.833740  45.328607
# 8         0.295028       0.000000  9.881313e-324  980.833740  45.328607
# ...            ...            ...            ...         ...        ...
# 48563     1.607175    2461.513184  1.389233e-316   34.545956   4.056387
# 48564     1.607175    2461.513184  1.389233e-316   34.545956   4.056387
# 48565     1.607175    2461.513184  1.389233e-316   34.545956   4.056387
# 48566     0.016811  553251.687500   0.000000e+00   38.519566  54.214864
# 48572     0.066943   20629.906250   0.000000e+00   19.274660  19.981537
#
#           bulge      Bfld         BH_AGN
# 1      0.155899  0.125910  9.881313e-324
# 2      0.155899  0.125910  9.881313e-324
# 6      0.155899  0.125910  9.881313e-324
# 7      0.155899  0.125910  9.881313e-324
# 8      0.155899  0.125910  9.881313e-324
# ...         ...       ...            ...
# 48563 -0.793238  0.072292   2.461513e+03
# 48564 -0.793238  0.072292   2.461513e+03
# 48565 -0.793238  0.072292   2.461513e+03
# 48566  0.083967  0.068477   5.532517e+05
# 48572 -0.021362  0.070190   2.062991e+04
#
# [32953 rows x 19 columns]

# %%
all_centrals_df.shape
# Out:
# (32953, 19)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
all_centrals_df = all_centrals_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "gas_mass","avg_gas_mass", "quenching_vector", "Bfld", "veldisp", "BH_AGN"])

# %%
all_centrals_df['avg_SFR'].hist()
# Out:
# <Axes: >

# %%
# this indicates that there are more instances of the delta rate on the left

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

galaxy_ids = all_centrals_df['subID']

feature_importances_list = []
feature_names = None
test_mses = []
train_mses = []


for seed in range(10):
    # split galaxies into 50% training and 50% testing
    unique_galaxies = np.unique(all_centrals_df['subID'])
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    # assign spaxels based on galaxy split
    train_data = all_centrals_df[all_centrals_df['subID'].isin(train_galaxies)]
    test_data = all_centrals_df[all_centrals_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['avg_SFR', 'subID']), train_data['avg_SFR']
    X_test, y_test = test_data.drop(columns=['avg_SFR', 'subID']), test_data['avg_SFR']
    
    
    if feature_names is None:
        feature_names = X_train.columns.tolist()

    scaler = RobustScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    param_grid = {
    'n_estimators': [100,200, 300, 400, 500],  
    'max_depth': [50, 100, 150, 200, 250],  
    'min_samples_split': [50, 100, 150],  
    'min_samples_leaf': [300, 400, 500, 600],  
    'max_features': [None], 
    'bootstrap': [True],
    }
    rf_regressor = RandomForestRegressor(random_state=seed, n_jobs=-1)
    cv = KFold(n_splits=5, shuffle=True, random_state=seed)

    random_search = RandomizedSearchCV(
    estimator=rf_regressor, 
    param_distributions=param_grid, 
    n_iter=10,
    cv=cv, 
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    random_state=seed,
    verbose=2)

    random_search.fit(X_train_scaled, y_train)

    best_rf_regressor = random_search.best_estimator_

    best_rf_regressor.fit(X_train_scaled, y_train)
    
    y_train_pred = best_rf_regressor.predict(X_train_scaled)
    y_test_pred = best_rf_regressor.predict(X_test_scaled)
    
    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)
    
    train_mses.append(train_mse)
    test_mses.append(test_mse)
    
    feature_importances_list.append(best_rf_regressor.feature_importances_)
#     print(random_search.best_params_)
    print(f"Run {seed+1}: Train MSE = {train_mse:.4f}, Test MSE = {test_mse:.4f}")

print("\nAverage MSE over 10 runs:")
print(f"Train MSE: Mean = {np.mean(train_mses):.4f}, Std = {np.std(train_mses):.4f}")
print(f"Test MSE:  Mean = {np.mean(test_mses):.4f}, Std = {np.std(test_mses):.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   9.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=  10.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=  10.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=400; total time=   9.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  10.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  11.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   8.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   9.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  11.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   5.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   7.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   8.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   8.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=   9.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  11.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   8.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   7.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   6.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=400; total time=   5.1s
# Run 1: Train MSE = 0.2609, Test MSE = 0.2797
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=  13.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=  13.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=  13.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=  14.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  10.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  11.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=  13.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  10.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   7.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   8.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   8.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   8.9s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   8.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  10.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  10.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=300; total time=   4.2s
# Run 2: Train MSE = 0.2528, Test MSE = 0.2821
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   8.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   8.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=  12.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=  14.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=  13.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=  14.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=  12.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=500; total time=  14.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  15.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  15.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  12.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  13.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  14.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  14.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  12.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  13.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  13.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  16.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  13.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  14.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   8.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=  11.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  12.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   3.0s
# Run 3: Train MSE = 0.2574, Test MSE = 0.2694
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  12.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  13.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   6.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  12.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  15.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  15.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  14.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  13.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=500; total time=  13.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  11.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  12.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   5.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   3.4s
# Run 4: Train MSE = 0.2614, Test MSE = 0.2683
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=  10.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=  10.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=  11.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=  10.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=400; total time=  10.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=  10.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   8.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   9.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   9.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=300; total time=   8.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   7.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   7.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   8.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   7.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   7.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   8.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   7.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=300; total time=   8.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  12.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  12.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   9.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   6.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   5.9s
# Run 5: Train MSE = 0.2530, Test MSE = 0.2763
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   6.3s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  11.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  11.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  11.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  11.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=500; total time=  10.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  13.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  12.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  13.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=500; total time=  12.3s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  11.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  11.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  11.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  12.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   9.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=500; total time=  11.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   9.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   9.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  10.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  12.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  11.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  12.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  10.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   7.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=  10.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   8.7s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=400; total time=   9.1s
# Run 6: Train MSE = 0.2610, Test MSE = 0.2734
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   7.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   7.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   8.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   9.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=300; total time=   7.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=50, n_estimators=200; total time=   5.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=  10.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=  10.5s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=  10.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=   9.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=400; total time=  10.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  10.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  11.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  11.0s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  11.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=500; total time=  11.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=  10.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=400; total time=   9.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=300; total time=   6.8s
# ...
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   9.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=  13.9s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=500; total time=  14.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   6.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   6.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   7.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   5.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   4.1s
# Run 8: Train MSE = 0.2610, Test MSE = 0.2717
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   5.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=200; total time=   4.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   6.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=100, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.1s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=100, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.6s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   7.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   8.0s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   7.8s
# [CV] END bootstrap=True, max_depth=250, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   6.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=300; total time=   7.4s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  13.2s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  13.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  12.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  14.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  12.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=600, min_samples_split=100, n_estimators=200; total time=   4.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  11.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  12.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  11.2s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  12.3s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=500; total time=  12.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  11.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=   6.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=   6.6s
# Run 9: Train MSE = 0.2594, Test MSE = 0.2661
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  11.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  12.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  12.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  12.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=  10.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=500; total time=  11.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=100, n_estimators=400; total time=   9.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  12.9s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  10.8s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  13.4s
# [CV] END bootstrap=True, max_depth=200, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  10.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  12.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  11.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.7s
# [CV] END bootstrap=True, max_depth=100, max_features=None, min_samples_leaf=500, min_samples_split=50, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=150, n_estimators=400; total time=  12.7s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=600, min_samples_split=50, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.0s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=500, min_samples_split=150, n_estimators=500; total time=  12.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.6s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  15.9s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.8s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  14.4s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=300, min_samples_split=50, n_estimators=500; total time=  15.1s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.7s
# [CV] END bootstrap=True, max_depth=50, max_features=None, min_samples_leaf=600, min_samples_split=150, n_estimators=300; total time=   6.8s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  13.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  13.6s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=  12.0s
# [CV] END bootstrap=True, max_depth=150, max_features=None, min_samples_leaf=400, min_samples_split=150, n_estimators=500; total time=   5.1s
# Run 10: Train MSE = 0.2603, Test MSE = 0.2733
#
# Average MSE over 10 runs:
# Train MSE: Mean = 0.2585, Std = 0.0031
# Test MSE:  Mean = 0.2730, Std = 0.0048

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("All Centrals Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 1  avg_s_mass         0.710101  0.008906
# 3      BHMass         0.162779  0.011689
# 6       bulge         0.100005  0.009133
# 2      s_mass         0.012001  0.006649
# 4       Mhalo         0.007446  0.007038
# 0   bin_radii         0.006853  0.002336
# 5    overdens         0.000815  0.000577

# %%
all_centrals_df.corr()
# Out:
#                subID  bin_radii  avg_s_mass   avg_SFR    s_mass    BHMass  \
# subID       1.000000  -0.012809   -0.296515  0.149123 -0.761148 -0.734478
# bin_radii  -0.012809   1.000000   -0.764428 -0.505080 -0.020475 -0.025588
# avg_s_mass -0.296515  -0.764428    1.000000  0.570652  0.160817  0.153218
# avg_SFR     0.149123  -0.505080    0.570652  1.000000 -0.175206 -0.173940
# s_mass     -0.761148  -0.020475    0.160817 -0.175206  1.000000  0.985867
# BHMass     -0.734478  -0.025588    0.153218 -0.173940  0.985867  1.000000
# Mhalo      -0.622858  -0.021604    0.085471 -0.151644  0.916946  0.902858
# overdens   -0.145762   0.002560    0.041921  0.037902  0.186934  0.159274
# bulge      -0.532636   0.018749    0.100816 -0.316198  0.393057  0.381536
#
#                Mhalo  overdens     bulge
# subID      -0.622858 -0.145762 -0.532636
# bin_radii  -0.021604  0.002560  0.018749
# avg_s_mass  0.085471  0.041921  0.100816
# avg_SFR    -0.151644  0.037902 -0.316198
# s_mass      0.916946  0.186934  0.393057
# BHMass      0.902858  0.159274  0.381536
# Mhalo       1.000000  0.292439  0.288202
# overdens    0.292439  1.000000  0.029837
# bulge       0.288202  0.029837  1.000000

# %%
import os
# Define your directory and file name
directory = 'rf_regression_outputs'
filename = 'all_centrals_rf_reg.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to rf_regression_outputs/all_centrals_rf_reg.csv

# %%
train_mean = round(np.mean(train_mses), 2)
test_mean = round(np.mean(test_mses), 2)

df = pd.DataFrame({
    'Train MSE': [train_mean],
    'Test MSE': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'rf_regression_outputs'
filename = 'all_centrals_rf_reg_mse.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
#    Train MSE  Test MSE
# 0       0.26      0.27
# DataFrame saved to rf_regression_outputs/all_centrals_rf_reg_mse.csv

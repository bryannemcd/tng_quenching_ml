# %%
import pandas as pd
import numpy as np

# %%
high_mass_satellite_df = pd.read_parquet ('../high_mass_satellite_df_annuli_revised.parquet')

# %%
high_mass_satellite_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 91          1.0   0.037018   10.065946 -1.977420      6.628361
# 92          1.0   0.111053    9.816378 -2.138036      6.690369
# 93          1.0   0.185088    9.498950 -2.488943      6.717174
# 94          1.0   0.259123    9.273945 -2.704103      6.806918
# 95          1.0   0.333158    9.124043 -2.386751      7.096273
# ...         ...        ...         ...       ...           ...
# 33561  476528.0   0.179965    9.485483 -2.459436      7.232764
# 33562  476528.0   0.539895    9.195900 -2.790333      6.889097
# 33563  476528.0   0.899825    8.818249 -3.192451      6.611662
# 33564  476528.0   1.259755    8.497334 -3.498477      6.271559
# 33565  476528.0   1.619685    8.209693 -3.762227      5.799985
#
#        quenching_vector     gas_mass     s_mass    BHMass  class    veldisp  \
# 91                    0  5069.831055  55.879173  0.125518      1  333.89325
# 92                    0  5069.831055  55.879173  0.125518      1  333.89325
# 93                    1  5069.831055  55.879173  0.125518      1  333.89325
# 94                    1  5069.831055  55.879173  0.125518      1  333.89325
# 95                    0  5069.831055  55.879173  0.125518      1  333.89325
# ...                 ...          ...        ...       ...    ...        ...
# 33561                 1     0.000000   3.387989  0.010589      1  112.13295
# 33562                 1     0.000000   3.387989  0.010589      1  112.13295
# 33563                 1     0.000000   3.387989  0.010589      1  112.13295
# 33564                 1     0.000000   3.387989  0.010589      1  112.13295
# 33565                 1     0.000000   3.387989  0.010589      1  112.13295
#
#        global_SFRs      BH_cumQM       BH_cumRM         Mhalo     overdens  \
# 91        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# 92        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# 93        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# 94        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# 95        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# ...            ...           ...            ...           ...          ...
# 33561     0.018142  1.015537e+06   0.000000e+00    121.820320     6.780018
# 33562     0.018142  1.015537e+06   0.000000e+00    121.820320     6.780018
# 33563     0.018142  1.015537e+06   0.000000e+00    121.820320     6.780018
# 33564     0.018142  1.015537e+06   0.000000e+00    121.820320     6.780018
# 33565     0.018142  1.015537e+06   0.000000e+00    121.820320     6.780018
#
#           bulge      Bfld        BH_AGN
# 91     0.508532  0.152681  9.718077e+07
# 92     0.508532  0.152681  9.718077e+07
# 93     0.508532  0.152681  9.718077e+07
# 94     0.508532  0.152681  9.718077e+07
# 95     0.508532  0.152681  9.718077e+07
# ...         ...       ...           ...
# 33561  0.403195  0.133146  1.015537e+06
# 33562  0.403195  0.133146  1.015537e+06
# 33563  0.403195  0.133146  1.015537e+06
# 33564  0.403195  0.133146  1.015537e+06
# 33565  0.403195  0.133146  1.015537e+06
#
# [8675 rows x 19 columns]

# %%
# # calculating star forming efficiency (SFE) and gas fraction 
# low_mass_satellite_df['SFE'] = 10**(low_mass_satellite_df['avg_SFR'] - low_mass_satellite_df['avg_gas_mass'])
# low_mass_satellite_df['f_gas'] = 10**(low_mass_satellite_df['avg_gas_mass'] - low_mass_satellite_df['avg_s_mass'])

# %%
# # remove the rows where the sfr_indicator is 0.0 -> implies artificially imposed minimum
# low_mass_satellite_df = low_mass_satellite_df[low_mass_satellite_df['sfr_indicator'] != 0.0]
# low_mass_satellite_df

# %%
# star forming quenching vector value = 0
high_mass_satellite_df = high_mass_satellite_df[high_mass_satellite_df['quenching_vector'] != 1]
high_mass_satellite_df
# Out:
#           subID  bin_radii  avg_s_mass   avg_SFR  avg_gas_mass  \
# 91          1.0   0.037018   10.065946 -1.977420      6.628361
# 92          1.0   0.111053    9.816378 -2.138036      6.690369
# 95          1.0   0.333158    9.124043 -2.386751      7.096273
# 96          1.0   0.407193    8.987732 -2.176390      6.971650
# 100         1.0   0.703334    8.643079 -3.075773      6.927053
# ...         ...        ...         ...       ...           ...
# 31450  462987.0   0.173652    9.171778 -0.202319      8.651024
# 31451  462987.0   0.520957    8.854676 -0.765807      8.399230
# 31452  462987.0   0.868261    8.582487 -1.080499      8.100421
# 31453  462987.0   1.215566    8.400651 -1.433384      7.964696
# 31454  462987.0   1.562870    8.203698 -1.477430      7.840324
#
#        quenching_vector     gas_mass     s_mass    BHMass  class     veldisp  \
# 91                    0  5069.831055  55.879173  0.125518      1  333.893250
# 92                    0  5069.831055  55.879173  0.125518      1  333.893250
# 95                    0  5069.831055  55.879173  0.125518      1  333.893250
# 96                    0  5069.831055  55.879173  0.125518      1  333.893250
# 100                   0  5069.831055  55.879173  0.125518      1  333.893250
# ...                 ...          ...        ...       ...    ...         ...
# 31450                 0     0.000000   2.001361  0.003254      1   83.934608
# 31451                 0     0.000000   2.001361  0.003254      1   83.934608
# 31452                 0     0.000000   2.001361  0.003254      1   83.934608
# 31453                 0     0.000000   2.001361  0.003254      1   83.934608
# 31454                 0     0.000000   2.001361  0.003254      1   83.934608
#
#        global_SFRs      BH_cumQM       BH_cumRM         Mhalo     overdens  \
# 91        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# 92        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# 95        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# 96        0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# 100       0.197048  9.718077e+07  6.904271e-310  38878.035156  8780.408392
# ...            ...           ...            ...           ...          ...
# 31450     2.233273  7.552357e+01   0.000000e+00    129.809052     0.046284
# 31451     2.233273  7.552357e+01   0.000000e+00    129.809052     0.046284
# 31452     2.233273  7.552357e+01   0.000000e+00    129.809052     0.046284
# 31453     2.233273  7.552357e+01   0.000000e+00    129.809052     0.046284
# 31454     2.233273  7.552357e+01   0.000000e+00    129.809052     0.046284
#
#           bulge      Bfld        BH_AGN
# 91     0.508532  0.152681  9.718077e+07
# 92     0.508532  0.152681  9.718077e+07
# 95     0.508532  0.152681  9.718077e+07
# 96     0.508532  0.152681  9.718077e+07
# 100    0.508532  0.152681  9.718077e+07
# ...         ...       ...           ...
# 31450 -1.015946  0.104524  7.552357e+01
# 31451 -1.015946  0.104524  7.552357e+01
# 31452 -1.015946  0.104524  7.552357e+01
# 31453 -1.015946  0.104524  7.552357e+01
# 31454 -1.015946  0.104524  7.552357e+01
#
# [4182 rows x 19 columns]

# %%
high_mass_satellite_df.shape
# Out:
# (4182, 19)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import RobustScaler

# 'BHMass', 'BHCum_QM', 'Mhalo', 'overdens', and 'bulge' are the features wer are testing
high_mass_satellite_df = high_mass_satellite_df.drop(columns=["class", "BH_cumQM", "BH_cumRM", "global_SFRs", "gas_mass","avg_gas_mass", "quenching_vector", "Bfld", "veldisp", "BH_AGN"])

# %%
high_mass_satellite_df['avg_SFR'].hist()
# Out:
# <Axes: >

# %%
# this indicates that there are more instances of the delta rate on the left

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

galaxy_ids = high_mass_satellite_df['subID']

feature_importances_list = []
feature_names = None
test_mses = []
train_mses = []


for seed in range(10):
    # split galaxies into 50% training and 50% testing
    unique_galaxies = np.unique(high_mass_satellite_df['subID'])
    train_galaxies, test_galaxies = train_test_split(unique_galaxies, test_size=0.5, random_state=seed)

    # assign spaxels based on galaxy split
    train_data = high_mass_satellite_df[high_mass_satellite_df['subID'].isin(train_galaxies)]
    test_data = high_mass_satellite_df[high_mass_satellite_df['subID'].isin(test_galaxies)]

    X_train, y_train = train_data.drop(columns=['avg_SFR', 'subID']), train_data['avg_SFR']
    X_test, y_test = test_data.drop(columns=['avg_SFR', 'subID']), test_data['avg_SFR']
    
    
    if feature_names is None:
        feature_names = X_train.columns.tolist()

    scaler = RobustScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    cv = KFold(n_splits=5, shuffle=True, random_state=seed)

    # XGBoost Regressor
    xgb_regressor = XGBRegressor(random_state=seed, n_jobs=-1)

    param_grid = {
    'n_estimators': [250, 300],
    'max_depth': [2],
    'learning_rate': [0.01],
    'subsample': [0.6, 0.7],
    'colsample_bytree': [1.0],
    'min_child_weight': [30, 40, 50],
    'reg_alpha': [8, 12, 15],
    'reg_lambda': [25, 30, 35]
}


    grid_search = GridSearchCV(
    estimator=xgb_regressor, 
    param_grid=param_grid, 
    cv=5, 
    scoring='neg_mean_squared_error',
    n_jobs=-1, 
    verbose=2
    )

    grid_search.fit(X_train_scaled, y_train)

    best_xg_regressor = grid_search.best_estimator_

    best_xg_regressor.fit(X_train_scaled, y_train)
    
    y_train_pred = best_xg_regressor.predict(X_train_scaled)
    y_test_pred = best_xg_regressor.predict(X_test_scaled)
    
    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)
    
    train_mses.append(train_mse)
    test_mses.append(test_mse)
    
    feature_importances_list.append(best_xg_regressor.feature_importances_)
#     print(random_search.best_params_)
    print(f"Run {seed+1}: Train MSE = {train_mse:.4f}, Test MSE = {test_mse:.4f}")

print("\nAverage MSE over 10 runs:")
print(f"Train MSE: Mean = {np.mean(train_mses):.4f}, Std = {np.std(train_mses):.4f}")
print(f"Test MSE:  Mean = {np.mean(test_mses):.4f}, Std = {np.std(test_mses):.4f}")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s[CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
#
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=30, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s[CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
#
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=40, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# ...
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=250, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=8, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=12, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=25, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=2, min_child_weight=50, n_estimators=300, reg_alpha=15, reg_lambda=35, subsample=0.7; total time=   0.1s
# Run 10: Train MSE = 0.2465, Test MSE = 0.2997
#
# Average MSE over 10 runs:
# Train MSE: Mean = 0.2443, Std = 0.0093
# Test MSE:  Mean = 0.2937, Std = 0.0138

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
feature_colors = {
    'bin_radii': '#77AADD',
    'avg_s_mass': '#EE8866',
    's_mass': '#FFAABB',
    'BHMass': '#99DDFF',
    'Mhalo': '#44BB99',
    'overdens': '#BBCC33',
    'bulge': '#AAAA00',
    'BH_AGN': '#DDDDDD',
}

# importances + stds across 10 runs
importances_array = np.array(feature_importances_list)
importance_means = np.mean(importances_array, axis=0)
importance_stds = np.std(importances_array, axis=0)

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Mean Importance': importance_means,
    'Std Dev': importance_stds
}).sort_values(by='Mean Importance', ascending=False)

print("\n=== Average Feature Importances ===")
print(importance_df)

colors = [feature_colors[feat] for feat in importance_df['Feature']]
# Plot
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'], importance_df['Mean Importance'], yerr=importance_df['Std Dev'], capsize=5, color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Feature Importance")
plt.title("HMS Feature Importances with Error Bars (±1 Std Dev)")
plt.tight_layout()
plt.show()
# Out:
# === Average Feature Importances ===
#       Feature  Mean Importance   Std Dev
# 1  avg_s_mass         0.372557  0.039264
# 3      BHMass         0.206122  0.030312
# 6       bulge         0.186780  0.018149
# 2      s_mass         0.072766  0.031001
# 0   bin_radii         0.066184  0.030225
# 5    overdens         0.054238  0.017828
# 4       Mhalo         0.041353  0.014794

# %%
high_mass_satellite_df.corr()
# Out:
#                subID  bin_radii  avg_s_mass   avg_SFR    s_mass    BHMass  \
# subID       1.000000   0.051183   -0.139739  0.193489 -0.506293 -0.524638
# bin_radii   0.051183   1.000000   -0.854847 -0.439338 -0.018352 -0.029140
# avg_s_mass -0.139739  -0.854847    1.000000  0.448356  0.116181  0.129623
# avg_SFR     0.193489  -0.439338    0.448356  1.000000 -0.152944 -0.181341
# s_mass     -0.506293  -0.018352    0.116181 -0.152944  1.000000  0.966830
# BHMass     -0.524638  -0.029140    0.129623 -0.181341  0.966830  1.000000
# Mhalo      -0.844580  -0.062053    0.143283 -0.139480  0.458484  0.483518
# overdens   -0.062220   0.003857    0.025217  0.021468  0.113893  0.186801
# bulge      -0.371414   0.006085    0.060950 -0.432192  0.308153  0.327534
#
#                Mhalo  overdens     bulge
# subID      -0.844580 -0.062220 -0.371414
# bin_radii  -0.062053  0.003857  0.006085
# avg_s_mass  0.143283  0.025217  0.060950
# avg_SFR    -0.139480  0.021468 -0.432192
# s_mass      0.458484  0.113893  0.308153
# BHMass      0.483518  0.186801  0.327534
# Mhalo       1.000000  0.005214  0.296056
# overdens    0.005214  1.000000  0.017226
# bulge       0.296056  0.017226  1.000000

# %%
import os
# Define your directory and file name
directory = 'xg_regression_outputs'
filename = 'hms_xg_reg.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
importance_df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
# DataFrame saved to xg_regression_outputs/hms_xg_reg.csv

# %%
train_mean = round(np.mean(train_mses), 2)
test_mean = round(np.mean(test_mses), 2)

df = pd.DataFrame({
    'Train MSE': [train_mean],
    'Test MSE': [test_mean]
})

print(df)
import os
# Define your directory and file name
directory = 'xg_regression_outputs'
filename = 'hms_xg_reg_mse.csv'
filepath = os.path.join(directory, filename)

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame
df.to_csv(filepath, index=False)

print(f'DataFrame saved to {filepath}')
# Out:
#    Train MSE  Test MSE
# 0       0.24      0.29
# DataFrame saved to xg_regression_outputs/hms_xg_reg_mse.csv

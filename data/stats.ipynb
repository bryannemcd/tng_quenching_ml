# %% [markdown]
# # Dataset statistics

# %%
import pandas as pd

# %%
low_mass_satellite_df = pd.read_parquet ('low_mass_satellite_df_annuli_revised.parquet')


#new_low_mass_satellite_df = low_mass_satellite_df[low_mass_satellite_df['BHMass']>0]



print("Number in the dataset:", len(low_mass_satellite_df))
(low_mass_satellite_df['BHMass']>0).sum()
print('Number with BHMass=0:', len(low_mass_satellite_df)-(low_mass_satellite_df['BHMass']>0).sum())
print('Number of unique subID values:', low_mass_satellite_df['subID'].nunique())
print('Number of rows with BHMass=0:', (low_mass_satellite_df['BHMass']==0.0).sum())
print('Number of unique subID with BHMass=0:', low_mass_satellite_df[low_mass_satellite_df['BHMass']==0.0]['subID'].nunique())
# Out:
# Number in the dataset: 5831
# Number with BHMass=0: 541
# Number of unique subID values: 825
# Number of rows with BHMass=0: 541
# Number of unique subID with BHMass=0: 94

# %%
high_mass_satellite_df = pd.read_parquet ('high_mass_satellite_df_annuli_revised.parquet')
print("Number of galaxies in the dataset:", len(high_mass_satellite_df))
print('Number with BHMass=0:', len(high_mass_satellite_df)-(high_mass_satellite_df['BHMass']>0).sum())

print('Number of unique subID with BHMass=0:', high_mass_satellite_df[high_mass_satellite_df['BHMass']==0.0]['subID'].nunique())
# Out:
# Number of galaxies in the dataset: 8675
# Number with BHMass=0: 57
# Number of unique subID with BHMass=0: 5

# %%
high_mass_central_df = pd.read_parquet ('high_mass_central_df_annuli_revised.parquet')
print("Number of galaxies in the dataset:", len(high_mass_central_df))
print('Number with BHMass=0:', len(high_mass_central_df)-(high_mass_central_df['BHMass']>0).sum())
print('Number of unique subID with BHMass=0:', high_mass_central_df[high_mass_central_df['BHMass']==0.0]['subID'].nunique())
# Out:
# Number of galaxies in the dataset: 26899
# Number with BHMass=0: 0
# Number of unique subID with BHMass=0: 0

# %%
low_mass_central_df = pd.read_parquet ('low_mass_central_df_annuli_revised.parquet')
print("Number of galaxies in the dataset:", len(low_mass_central_df))
print('Number with BHMass=0:', len(low_mass_central_df)-(low_mass_central_df['BHMass']>0).sum())
print('Number of unique subID with BHMass=0:', low_mass_central_df[low_mass_central_df['BHMass']==0.0]['subID'].nunique())
print('Mhalo for low mass central with BHMass=0:')
print(low_mass_central_df[low_mass_central_df['BHMass']==0.0].drop_duplicates(subset=['subID'])['Mhalo'].values)
# Out:
# Number of galaxies in the dataset: 21677
# Number with BHMass=0: 50
# Number of unique subID with BHMass=0: 8
# Mhalo for low mass central with BHMass=0:
# [8.025561  7.9086576 4.837298  6.281879  4.553244  2.6261446 3.1148257
#  2.8207803]
